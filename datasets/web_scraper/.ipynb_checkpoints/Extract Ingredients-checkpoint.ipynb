# %%
import pandas as pd

# %%
data_root = "recipebox"

# %%
from glob import glob
datasets = glob(data_root + "/recipes*.json")
datasets = datasets[1], datasets[0], datasets[2]

# %%
stoppers = (",", ";") # stop reading the string here

measure_words = (
    # from https://en.wikipedia.org/wiki/Cooking_weights_and_measures#United_States_measures
    "scant",
    "drop",
    "smidgen",
    "pinch",
    "dash",
    "head",
    "piece",
    "splash",
    "squeeze",
    # from # from https://en.wikibooks.org/wiki/Cookbook:Units_of_measurement
    # fluid
    "teaspoon","t", "tsp",
    "tablespoon", "T", "tbl", "tbs", "tbsp", 
    "fluid ounce", "fl oz",
    "gill",
    "cup", "c",
    "pint", "p", "pt", "fl pt",
    "quart", "q", "qt", "fl qt",
    "gallon", "g", "gal",
    "ml", "milliliter", "millilitre", "cc",
    "l", "liter", "litre",
    "dl", "deciliter", "decilitre",
    "can",
    "bottle",
    # weight
    "pound", "lb" "#",
    "ounce", "oz",
    "mg", "milligram", "milligramme",
    "g", "gram", "gramme",
    "kg", "kilogram", "kilogramme",
    # length
    "mm", "millimeter", "millimetre",
    "cm", "centimeter", "centimetre",
    "m", "meter", "metre",
    "inch", "in",
    # size
    "large",
    "medium",
    "small",
    "about",
    # quantifiers
    "half",
    "single",
    "couple",
    "dozen",
    "many",
    "each",
    "some",
    "every",
    "pair",
    "additional",
    "approx"
    # misc
    "bag",
    "box",
    "handful",
    "slice",
    "end",
    "accompaniment"
)


adjective_endings = ("ly",) # remove any word that ends with this
verb_endings = ("ed",) # e.g. packed, melted, chopped, chilled, divided, trimmed, grated
endings = verb_endings + adjective_endings
endings

to_remove = (
    "advertisement", 
    "of", "a", "the", "an",
    "to", "about", "from", "at", "by", "as", "above", "below", "abs",
    "recipe",
    "favorite", "choice", 
    "fat", "free", "taste", "garnish",
    "baby", "plump", "pure", "simple", "fresh", "torn", "good", "quality", "brand", "new"
    "very",
    
)
cardinal_numbers = ("one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen", "sixteen", "seventeen", "eighteen", "nineteen", "twenty")

# %%
import re

def lower(string):
    return string.lower()

def remove_after_stopper(string):
    # remove after any comma, colon, or period
    return re.sub(r"[,;\.].*", "", string)

def remove_between_paren(string):
    # \( and \) for parentheses characters
    return re.sub(r"\(.*\)", "", string)

def remove_measure_words(string):
    for m in measure_words:
        # greater than 1, don't want to apply to single letters. E.g. c for cups
        if len(m) > 1:
            # \b word boundary, %s the measure word, [a-zA-Z]* any number of following letters, \b word boundary
            string = re.sub(r"\b%s[a-zA-z]*\b" %m, "", string)
        else:
            string = re.sub(r"\b%s\b" %m, "", string)
    return string

def remove_nonalpha(string):
    # first replace dashes with spaces
    string = string.replace("-", " ")
    # ^ not, [a-zA-z] letter, \s space
    return re.sub(r"[^a-zA-Z\s]", "", string)

def remove_endings(string):
    for end in endings:
        string = re.sub(r"\b[\w]+%s\b" %end, "", string)
    return string

def remove_less_than(num):
    def remove_less_than_from_str(string):
        # remove words with less than num letters
        return re.sub(r"\b[\w]{%s}\b" % ",".join(str(i) for i in range(1,num+1)), "", string)
    return remove_less_than_from_str

def remove_dumb_words(string):
    for word in to_remove + cardinal_numbers:
        string = re.sub(r"\b%s\b" % word, "", string)
    return string

def remove_available_at(string):
    """ remove 'available at *** markets' """
    return re.sub(r"available at.*markets", "", string)

def remove_extra_spaces(string):
    return re.sub(r"\s+", " ", string)

def strip(string):
    return string.strip()

import functools
def compose(*functions):
    # we have to reverse to get in the desired order
    functions = reversed(functions)
    return functools.reduce(lambda f, g: lambda x: f(g(x)), functions, lambda x: x)

functions = (
    lower,
    remove_after_stopper, 
    remove_between_paren, 
    remove_measure_words, 
    remove_nonalpha, 
    remove_endings,
    remove_less_than(2),
    remove_dumb_words,
    remove_available_at,
    remove_extra_spaces, 
    strip
)
extract_ingredient = compose(*functions)

# %%
re.split("and|or", "tomatoes and potatos")
# Out:
# ['tomatoes ', ' potatos']

# %%
from tqdm import tqdm_notebook as tqdm
from collections import defaultdict
import numpy as np

ingredients = defaultdict(int)

for ds in tqdm(datasets, desc="Dataset"):
    print("Loading dataset", ds)
    df = pd.read_json(ds)
    all_ingredient_lists = df.loc["ingredients"]
    for ingredient_list in tqdm(all_ingredient_lists, desc="recipes"):
        try:
            if type(ingredient_list) != list:
                continue
            for ingredient_string in ingredient_list:
                
                # SPLIT THE INGREDIENT STRING ON AND AND OR
                parts = re.split(r"\band\b|\bor\b|\bplus\b", ingredient_string)
                if len(parts) > 1:
                    ingredient_list += parts[1:]
                    ingredient_string = parts[0]
                
                ingredient = extract_ingredient(ingredient_string)
                if ingredient: # ignore empty string
                    ingredients[ingredient] += 1
        except Exception as e:
            print(f"Warning! failed on {str(ingredient_list)}")
            print(e)
# Out:
# HBox(children=(IntProgress(value=0, description='Dataset', max=3, style=ProgressStyle(description_width='initi…
# Loading dataset recipebox/recipes_raw_nosource_ar.json
# HBox(children=(IntProgress(value=0, description='recipes', max=39802, style=ProgressStyle(description_width='i…
# Loading dataset recipebox/recipes_raw_nosource_epi.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0757eb67e092> in <module>
#       7 for ds in tqdm(datasets, desc="Dataset"):
#       8     print("Loading dataset", ds)
# ----> 9     df = pd.read_json(ds)
#      10     all_ingredient_lists = df.loc["ingredients"]
#      11     for ingredient_list in tqdm(all_ingredient_lists, desc="recipes"):
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     554         obj = None
#     555         if typ == 'frame':
# --> 556             obj = FrameParser(json, **kwargs).parse()
#     557
#     558         if typ == 'series' or obj is None:
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in parse(self)
#     656         if self.convert_axes:
#     657             self._convert_axes()
# --> 658         self._try_convert_types()
#     659         return self.obj
#     660
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in _try_convert_types(self)
#     917
#     918         self._process_converter(
# --> 919             lambda col, c: self._try_convert_data(col, c, convert_dates=False))
#     920
#     921     def _try_convert_dates(self):
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in _process_converter(self, f, filt)
#     897         for i, (col, c) in enumerate(self.obj.iteritems()):
#     898             if filt(col, c):
# --> 899                 new_data, result = f(col, c)
#     900                 if result:
#     901                     c = new_data
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in <lambda>(col, c)
#     917
#     918         self._process_converter(
# --> 919             lambda col, c: self._try_convert_data(col, c, convert_dates=False))
#     920
#     921     def _try_convert_dates(self):
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/io/json/json.py in _try_convert_data(self, name, data, use_dtypes, convert_dates)
#     728             # coerce ints if we can
#     729             try:
# --> 730                 new_data = data.astype('int64')
#     731                 if (new_data == data).all():
#     732                     data = new_data
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5680                     results.append(results.append(col.copy() if copy else col))
#    5681
# -> 5682         elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5683             # GH 18099/22869: columnwise conversion to extension dtype
#    5684             # GH 24704: use iloc to handle duplicate column names
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1747     dtype = getattr(arr_or_dtype, 'dtype', arr_or_dtype)
#    1748     return (isinstance(dtype, ExtensionDtype) or
# -> 1749             registry.find(dtype) is not None)
#    1750
#    1751
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py in find(self, dtype)
#      87         for dtype_type in self.dtypes:
#      88             try:
# ---> 89                 return dtype_type.construct_from_string(dtype)
#      90             except TypeError:
#      91                 pass
#
# ~/.conda/envs/pt/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py in construct_from_string(cls, string)
#     697                 # TODO(py3): Change this pass to `raise TypeError(msg) from e`
#     698                 pass
# --> 699             raise TypeError(msg.format(string))
#     700
#     701         raise TypeError("Could not construct DatetimeTZDtype")
#
# KeyboardInterrupt:

# %%
def order(my_dict):
    return sorted(my_dict.items(), key=lambda x:x[1], reverse=True)

# %%
len(ingredients)
# Out:
# 15065

# %%
order(ingredients)[:200]
# Out:
# [('salt', 19393),
#  ('butter', 12443),
#  ('white sugar', 11128),
#  ('all purpose flour', 8783),
#  ('onion', 8140),
#  ('ground black pepper', 7948),
#  ('eggs', 6834),
#  ('water', 6825),
#  ('milk', 6125),
#  ('olive oil', 5703),
#  ('vanilla extract', 5648),
#  ('cloves garlic', 4721),
#  ('vegetable oil', 4089),
#  ('brown sugar', 4004),
#  ('ground cinnamon', 3877),
#  ('pepper', 3218),
#  ('baking powder', 3198),
#  ('baking soda', 3034),
#  ('egg', 3026),
#  ('lemon juice', 2761),
#  ('more', 2679),
#  ('garlic powder', 2195),
#  ('parmesan cheese', 2194),
#  ('parsley', 2079),
#  ('garlic', 1778),
#  ('skinless', 1756),
#  ('confectioners sugar', 1736),
#  ('cheddar cheese', 1732),
#  ('clove garlic', 1697),
#  ('carrots', 1681),
#  ('honey', 1658),
#  ('sour cream', 1642),
#  ('ground nutmeg', 1622),
#  ('walnuts', 1615),
#  ('mayonnaise', 1603),
#  ('soy sauce', 1575),
#  ('oregano', 1561),
#  ('green bell pepper', 1510),
#  ('potatoes', 1491),
#  ('tomatoes', 1475),
#  ('basil', 1462),
#  ('ground cumin', 1409),
#  ('cayenne pepper', 1403),
#  ('chicken broth', 1333),
#  ('green onions', 1306),
#  ('worcestershire sauce', 1281),
#  ('bell pepper', 1255),
#  ('paprika', 1252),
#  ('bacon', 1251),
#  ('cilantro', 1222),
#  ('cornstarch', 1215),
#  ('package cream cheese', 1180),
#  ('pecans', 1177),
#  ('margarine', 1169),
#  ('mushrooms', 1135),
#  ('chili powder', 1069),
#  ('pepper flakes', 1040),
#  ('ground beef', 1014),
#  ('onions', 1012),
#  ('extra virgin olive oil', 999),
#  ('celery', 998),
#  ('shortening', 971),
#  ('raisins', 966),
#  ('cocoa powder', 961),
#  ('ground ginger', 960),
#  ('black pepper', 960),
#  ('thyme', 955),
#  ('heavy cream', 949),
#  ('lemon', 937),
#  ('coconut', 893),
#  ('orange juice', 892),
#  ('lime juice', 873),
#  ('white vinegar', 846),
#  ('mozzarella cheese', 845),
#  ('sugar', 835),
#  ('kosher salt', 806),
#  ('zucchini', 805),
#  ('almonds', 804),
#  ('heavy whipping cream', 793),
#  ('ketchup', 787),
#  ('ground cloves', 775),
#  ('onion powder', 768),
#  ('tomato sauce', 751),
#  ('semisweet chocolate chips', 742),
#  ('cooking spray', 736),
#  ('stalks celery', 692),
#  ('egg whites', 690),
#  ('tomato', 689),
#  ('oil', 676),
#  ('carrot', 676),
#  ('oats', 664),
#  ('hot pepper sauce', 649),
#  ('tomato paste', 635),
#  ('egg yolks', 616),
#  ('buttermilk', 607),
#  ('rosemary', 607),
#  ('sea salt', 600),
#  ('balsamic vinegar', 587),
#  ('shrimp', 578),
#  ('strawberries', 574),
#  ('dill', 572),
#  ('garlic salt', 569),
#  ('dijon mustard', 568),
#  ('ginger', 567),
#  ('ginger root', 562),
#  ('warm water', 557),
#  ('sesame oil', 556),
#  ('lemon zest', 552),
#  ('lean ground beef', 545),
#  ('peanut butter', 544),
#  ('green onion', 524),
#  ('cold water', 523),
#  ('curry powder', 523),
#  ('boiling water', 520),
#  ('lime', 508),
#  ('wine vinegar', 497),
#  ('pineapple', 497),
#  ('jalapeno pepper', 493),
#  ('whole wheat flour', 487),
#  ('white wine', 476),
#  ('cabbage', 473),
#  ('cranberries', 473),
#  ('ground allspice', 453),
#  ('apples', 451),
#  ('almond extract', 450),
#  ('yellow onion', 444),
#  ('chicken stock', 442),
#  ('bread crumbs', 437),
#  ('italian seasoning', 436),
#  ('bay leaf', 432),
#  ('packages cream cheese', 424),
#  ('feta cheese', 415),
#  ('black beans', 411),
#  ('cream', 408),
#  ('ground turmeric', 407),
#  ('bay leaves', 406),
#  ('ham', 406),
#  ('maple syrup', 399),
#  ('beans', 396),
#  ('ice cubes', 396),
#  ('cucumber', 393),
#  ('pumpkin puree', 392),
#  ('black olives', 390),
#  ('sesame seeds', 389),
#  ('jalapeno peppers', 389),
#  ('cream cheese', 388),
#  ('white rice', 388),
#  ('coconut milk', 388),
#  ('cut', 387),
#  ('blueberries', 383),
#  ('spinach', 374),
#  ('orange zest', 373),
#  ('light brown sugar', 370),
#  ('dry bread crumbs', 364),
#  ('vegetable oil for frying', 363),
#  ('dry white wine', 360),
#  ('sweet onion', 345),
#  ('ground coriander', 344),
#  ('hot water', 341),
#  ('bananas', 340),
#  ('molasses', 338),
#  ('apple', 336),
#  ('banana', 336),
#  ('applesauce', 334),
#  ('ice', 331),
#  ('sage', 330),
#  ('mustard', 326),
#  ('sharp cheddar cheese', 325),
#  ('active dry yeast', 323),
#  ('sweet potatoes', 322),
#  ('avocado', 321),
#  ('flour tortillas', 317),
#  ('quick cooking oats', 316),
#  ('chives', 316),
#  ('apple cider vinegar', 315),
#  ('swiss cheese', 314),
#  ('bread flour', 314),
#  ('whole milk', 311),
#  ('cream tartar', 310),
#  ('cider vinegar', 308),
#  ('green beans', 306),
#  ('chicken', 306),
#  ('vegetable broth', 301),
#  ('plain yogurt', 300),
#  ('monterey jack cheese', 299),
#  ('beef broth', 296),
#  ('light corn syrup', 291),
#  ('container frozen topping', 288),
#  ('basil leaves', 284),
#  ('white onion', 283),
#  ('salsa', 282),
#  ('rice vinegar', 282),
#  ('pineapple juice', 280),
#  ('coconut oil', 276),
#  ('wine', 274),
#  ('egg yolk', 269),
#  ('container sour cream', 268),
#  ('roma tomatoes', 267),
#  ('stalk celery', 267),
#  ('ground cayenne pepper', 264)]

# %%
names, counts = zip(*order(ingredients))
sorted(names[:200])
# Out:
# ['active dry yeast',
#  'all purpose flour',
#  'almond extract',
#  'almonds',
#  'apple',
#  'apple cider vinegar',
#  'apples',
#  'applesauce',
#  'avocado',
#  'bacon',
#  'baking powder',
#  'baking soda',
#  'balsamic vinegar',
#  'banana',
#  'bananas',
#  'basil',
#  'basil leaves',
#  'bay leaf',
#  'bay leaves',
#  'beans',
#  'beef broth',
#  'bell pepper',
#  'black beans',
#  'black olives',
#  'black pepper',
#  'blueberries',
#  'boiling water',
#  'bread crumbs',
#  'bread flour',
#  'brown sugar',
#  'butter',
#  'buttermilk',
#  'cabbage',
#  'carrot',
#  'carrots',
#  'cayenne pepper',
#  'celery',
#  'cheddar cheese',
#  'chicken',
#  'chicken broth',
#  'chicken stock',
#  'chili powder',
#  'chives',
#  'cider vinegar',
#  'cilantro',
#  'clove garlic',
#  'cloves garlic',
#  'cocoa powder',
#  'coconut',
#  'coconut milk',
#  'coconut oil',
#  'cold water',
#  'confectioners sugar',
#  'container frozen topping',
#  'container sour cream',
#  'cooking spray',
#  'cornstarch',
#  'cranberries',
#  'cream',
#  'cream cheese',
#  'cream tartar',
#  'cucumber',
#  'curry powder',
#  'cut',
#  'dijon mustard',
#  'dill',
#  'dry bread crumbs',
#  'dry white wine',
#  'egg',
#  'egg whites',
#  'egg yolk',
#  'egg yolks',
#  'eggs',
#  'extra virgin olive oil',
#  'feta cheese',
#  'flour tortillas',
#  'garlic',
#  'garlic powder',
#  'garlic salt',
#  'ginger',
#  'ginger root',
#  'green beans',
#  'green bell pepper',
#  'green onion',
#  'green onions',
#  'ground allspice',
#  'ground beef',
#  'ground black pepper',
#  'ground cayenne pepper',
#  'ground cinnamon',
#  'ground cloves',
#  'ground coriander',
#  'ground cumin',
#  'ground ginger',
#  'ground nutmeg',
#  'ground turmeric',
#  'ham',
#  'heavy cream',
#  'heavy whipping cream',
#  'honey',
#  'hot pepper sauce',
#  'hot water',
#  'ice',
#  'ice cubes',
#  'italian seasoning',
#  'jalapeno pepper',
#  'jalapeno peppers',
#  'ketchup',
#  'kosher salt',
#  'lean ground beef',
#  'lemon',
#  'lemon juice',
#  'lemon zest',
#  'light brown sugar',
#  'light corn syrup',
#  'lime',
#  'lime juice',
#  'maple syrup',
#  'margarine',
#  'mayonnaise',
#  'milk',
#  'molasses',
#  'monterey jack cheese',
#  'more',
#  'mozzarella cheese',
#  'mushrooms',
#  'mustard',
#  'oats',
#  'oil',
#  'olive oil',
#  'onion',
#  'onion powder',
#  'onions',
#  'orange juice',
#  'orange zest',
#  'oregano',
#  'package cream cheese',
#  'packages cream cheese',
#  'paprika',
#  'parmesan cheese',
#  'parsley',
#  'peanut butter',
#  'pecans',
#  'pepper',
#  'pepper flakes',
#  'pineapple',
#  'pineapple juice',
#  'plain yogurt',
#  'potatoes',
#  'pumpkin puree',
#  'quick cooking oats',
#  'raisins',
#  'rice vinegar',
#  'roma tomatoes',
#  'rosemary',
#  'sage',
#  'salsa',
#  'salt',
#  'sea salt',
#  'semisweet chocolate chips',
#  'sesame oil',
#  'sesame seeds',
#  'sharp cheddar cheese',
#  'shortening',
#  'shrimp',
#  'skinless',
#  'sour cream',
#  'soy sauce',
#  'spinach',
#  'stalk celery',
#  'stalks celery',
#  'strawberries',
#  'sugar',
#  'sweet onion',
#  'sweet potatoes',
#  'swiss cheese',
#  'thyme',
#  'tomato',
#  'tomato paste',
#  'tomato sauce',
#  'tomatoes',
#  'vanilla extract',
#  'vegetable broth',
#  'vegetable oil',
#  'vegetable oil for frying',
#  'walnuts',
#  'warm water',
#  'water',
#  'white onion',
#  'white rice',
#  'white sugar',
#  'white vinegar',
#  'white wine',
#  'whole milk',
#  'whole wheat flour',
#  'wine',
#  'wine vinegar',
#  'worcestershire sauce',
#  'yellow onion',
#  'zucchini']

# %%
from difflib import SequenceMatcher

def similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()


def combine_similar(my_dict, ratio=0.65, combine_reverse=True):
    """
    combines similar keys in the dictionary
    
    assumes the relevant similar parts are at the end of the key
    """
    new_dict = defaultdict(int)
    
    # we sort by the tail ends. puts tail ends next to each other. better similarity this way.
    # e.g. "awesome lemon zest" and "weird lemon zest" are typically far apart.
    # sorting from the ends puts them next to each other
    sorted_keys = sorted(my_dict, key=lambda x: x[::-1].replace(" ", "Ω") if combine_reverse else x.replace(" ", "Ω")) 
    prev = ""
    for k in sorted_keys:
        if similarity(prev, k) > ratio:
            new_dict[prev] = my_dict[prev] + my_dict[k]
        else:
            new_dict[k] = my_dict[k]
            prev = k
    return new_dict

# %%
combined_ingredients = combine_similar(ingredients)
len(combined_ingredients)
# Out:
# 7807

# %%
order(combined_ingredients)[:500]
# Out:
# [('salt', 19993),
#  ('butter', 12443),
#  ('white sugar', 11129),
#  ('gluten multi purpose flour', 8784),
#  ('onion', 8140),
#  ('ground black pepper', 7953),
#  ('eggs', 6834),
#  ('water', 6829),
#  ('milk', 6125),
#  ('anise oil', 5714),
#  ('cloves garlic', 4734),
#  ('vegetable oil', 4090),
#  ('corn sugar', 4006),
#  ('cinnamon', 3991),
#  ('pepper', 3218),
#  ('meringue powder', 3202),
#  ('baking soda', 3034),
#  ('egg', 3026),
#  ('lemon juice', 2765),
#  ('bell pepper', 2765),
#  ('core', 2681),
#  ('carob powder', 2206),
#  ('parmesan cheese', 2195),
#  ('parsley', 2080),
#  ('garlic', 1790),
#  ('skinless', 1758),
#  ('confectioners sugar', 1742),
#  ('tomatoes', 1742),
#  ('cheddar cheese', 1733),
#  ('carrots', 1681),
#  ('honey', 1658),
#  ('sour cream', 1645),
#  ('ground nutmeg', 1625),
#  ('walnuts', 1615),
#  ('mayonnaise', 1604),
#  ('oregano', 1561),
#  ('potatoes', 1492),
#  ('basil', 1462),
#  ('cilantro', 1424),
#  ('ground cumin', 1412),
#  ('cayenne pepper', 1404),
#  ('paprika', 1373),
#  ('chicken broth', 1333),
#  ('green onions', 1307),
#  ('worcestershire sauce', 1286),
#  ('bacon', 1251),
#  ('cornstarch', 1216),
#  ('pecans', 1177),
#  ('margarine', 1175),
#  ('mushrooms', 1152),
#  ('chili powder', 1071),
#  ('shortening', 1067),
#  ('kelp flakes', 1041),
#  ('celery', 1019),
#  ('ground beef', 1015),
#  ('onions', 1012),
#  ('tuscan olive oil', 1000),
#  ('cocoa powder', 971),
#  ('raisins', 968),
#  ('ground ginger', 961),
#  ('black pepper', 961),
#  ('thyme', 955),
#  ('pastry cream', 951),
#  ('lemon', 937),
#  ('garlic cloves', 925),
#  ('orange juice', 895),
#  ('coconut', 894),
#  ('lime juice', 874),
#  ('mozzarella cheese', 849),
#  ('bulgar', 836),
#  ('apple', 833),
#  ('kosher salt', 818),
#  ('zucchini', 806),
#  ('almonds', 804),
#  ('ketchup', 788),
#  ('onion powder', 768),
#  ('tomato sauce', 752),
#  ('jumbo chocolate chips', 743),
#  ('tomato', 735),
#  ('stalks celery', 698),
#  ('whites', 692),
#  ('oil', 676),
#  ('carrot', 676),
#  ('oats', 664),
#  ('tabasco pepper sauce', 650),
#  ('rosemary', 643),
#  ('tomato paste', 636),
#  ('balsamic vinegar', 621),
#  ('yolks', 619),
#  ('buttermilk', 609),
#  ('shrimp', 599),
#  ('sesame oil', 586),
#  ('barberries', 575),
#  ('dill', 572),
#  ('blackberries', 571),
#  ('dijon mustard', 568),
#  ('warm water', 568),
#  ('ginger', 567),
#  ('ginger root', 563),
#  ('lemon zest', 553),
#  ('peanut butter', 544),
#  ('green onion', 530),
#  ('tonic water', 528),
#  ('bay powder', 524),
#  ('boiling water', 521),
#  ('serrano pepper', 518),
#  ('cabbage', 514),
#  ('champagne vinegar', 511),
#  ('lime', 509),
#  ('wheat flour', 489),
#  ('white wine', 479),
#  ('sauce', 465),
#  ('yellow onion', 460),
#  ('ground allspice', 459),
#  ('banana extract', 456),
#  ('apples', 452),
#  ('chicken stock', 443),
#  ('miami style cuban seasoning', 437),
#  ('bay leaf', 434),
#  ('turmeric', 418),
#  ('poblano peppers', 414),
#  ('black beans', 412),
#  ('cream', 408),
#  ('yellow leaves', 408),
#  ('ham', 406),
#  ('sage', 405),
#  ('beans', 402),
#  ('pancake syrup', 401),
#  ('vegetable oil for frying', 399),
#  ('sesame seeds', 398),
#  ('ice cubes', 397),
#  ('berries', 395),
#  ('pumpkin puree', 394),
#  ('cucumber', 394),
#  ('edam cheese', 392),
#  ('black olives', 392),
#  ('goat milk', 391),
#  ('mustard', 390),
#  ('white rice', 388),
#  ('banana', 387),
#  ('cut', 387),
#  ('white pepper', 375),
#  ('spinach', 374),
#  ('orange zest', 373),
#  ('dry bread crumbs', 366),
#  ('sweet onion', 347),
#  ('eagle milk', 345),
#  ('hot water', 342),
#  ('bananas', 341),
#  ('molasses', 338),
#  ('ice', 332),
#  ('dry yeast', 326),
#  ('chunks potatoes', 323),
#  ('quick cooking oats', 323),
#  ('avocado', 321),
#  ('flour tortillas', 318),
#  ('masa flour', 316),
#  ('chives', 316),
#  ('swiss cheese', 315),
#  ('vegetarian beans', 315),
#  ('stalk celery', 315),
#  ('cream tartar', 310),
#  ('cider vinegar', 309),
#  ('chicken', 306),
#  ('vegetable broth', 305),
#  ('beef broth', 305),
#  ('plain yogurt', 301),
#  ('monterey jack cheese', 300),
#  ('walnut oil', 294),
#  ('pickle juice', 290),
#  ('nuts', 290),
#  ('sorrel leaves', 285),
#  ('white onion', 284),
#  ('cold vinegar', 283),
#  ('salsa', 282),
#  ('wine', 275),
#  ('yellow mustard', 273),
#  ('yolk', 270),
#  ('container sour cream', 269),
#  ('meal', 265),
#  ('whole chicken', 261),
#  ('skim milk', 260),
#  ('orange', 257),
#  ('package frozen spinach', 256),
#  ('spicy beans', 256),
#  ('dole white', 251),
#  ('broccoli', 251),
#  ('shallots', 250),
#  ('safflower', 244),
#  ('quinoa', 235),
#  ('vinegar', 235),
#  ('goya wine vinegar', 235),
#  ('apple pie spice', 233),
#  ('hot sauce', 233),
#  ('marshmallows', 232),
#  ('beer', 231),
#  ('package mushrooms', 231),
#  ('brownie crust', 231),
#  ('filling', 230),
#  ('vodka', 228),
#  ('self rising flour', 227),
#  ('mini peppers', 226),
#  ('orange bell peppers', 226),
#  ('cracker crumbs', 225),
#  ('shortening for frying', 224),
#  ('peaches', 224),
#  ('dates', 221),
#  ('flour', 219),
#  ('whole cloves', 218),
#  ('less', 218),
#  ('cake flour', 215),
#  ('shallot', 214),
#  ('food coloring', 211),
#  ('horseradish sauce', 210),
#  ('broccoli florets', 208),
#  ('spaghetti', 203),
#  ('minute white rice', 202),
#  ('lemons', 202),
#  ('avocados', 200),
#  ('carrot chunks', 199),
#  ('dark brown sugar', 197),
#  ('ground turkey', 195),
#  ('rice', 193),
#  ('corn', 193),
#  ('black raisins', 193),
#  ('pine nuts', 193),
#  ('shoe peg corn', 192),
#  ('ricotta cheese', 191),
#  ('radish', 191),
#  ('mango', 187),
#  ('capers', 186),
#  ('bread', 184),
#  ('ground pork', 183),
#  ('mint', 181),
#  ('wheat berries', 178),
#  ('limes', 178),
#  ('nutmeg', 177),
#  ('topping', 177),
#  ('tarragon', 177),
#  ('eggplant', 177),
#  ('chocolate chips', 174),
#  ('chestnuts', 173),
#  ('garbanzo beans', 172),
#  ('rum', 170),
#  ('chicken bouillon', 170),
#  ('butternut squash', 169),
#  ('pork chops', 169),
#  ('meat', 168),
#  ('sugar cubes', 166),
#  ('mint leaves', 164),
#  ('pumpkin', 162),
#  ('italian bread crumbs', 161),
#  ('seeds', 161),
#  ('marjoram', 158),
#  ('cream sherry', 158),
#  ('american cheese', 157),
#  ('peppercorn seasoning', 157),
#  ('granny smith apples', 157),
#  ('cucumbers', 157),
#  ('peppermint oil', 156),
#  ('asparagus', 155),
#  ('poppy seeds', 154),
#  ('brandy', 154),
#  ('whole grain tortillas', 150),
#  ('tandoori masala', 148),
#  ('yellow squash', 148),
#  ('almond milk', 148),
#  ('beef stew meat', 148),
#  ('salmonberries', 146),
#  ('package linguine pasta', 145),
#  ('rhubarb', 145),
#  ('button mushrooms', 145),
#  ('artichoke hearts', 145),
#  ('cumin', 144),
#  ('thyme leaves', 144),
#  ('garlic butter', 143),
#  ('green peas', 143),
#  ('frozen peas', 142),
#  ('provolone cheese', 141),
#  ('cashews', 141),
#  ('romano cheese', 140),
#  ('tuna', 139),
#  ('cinnamon stick', 139),
#  ('brown rice', 138),
#  ('container chocolate', 138),
#  ('dressing', 137),
#  ('potato', 137),
#  ('peach halves', 137),
#  ('yam extract', 137),
#  ('lettuce', 135),
#  ('wheat germ', 134),
#  ('sunflower seeds', 134),
#  ('green cherries', 134),
#  ('hamburger buns', 134),
#  ('graham cracker crust', 134),
#  ('callaloo leaves', 133),
#  ('pie shell', 131),
#  ('corn syrup', 131),
#  ('liquid smoke flavoring', 130),
#  ('italian season bread crumbs', 130),
#  ('spinach leaves', 130),
#  ('sweet potato', 129),
#  ('white bread', 127),
#  ('package dry onion soup mix', 124),
#  ('chee fah chiles', 123),
#  ('crust', 123),
#  ('turkey', 123),
#  ('cake', 122),
#  ('ice cream', 122),
#  ('goya milk', 121),
#  ('water cover', 121),
#  ('seasoning salt', 121),
#  ('coffee liqueur', 120),
#  ('green grapes', 120),
#  ('maille old style mustard', 119),
#  ('honey mustard salad dressing', 118),
#  ('apricots', 118),
#  ('ground thyme', 117),
#  ('twist macaroni', 117),
#  ('bunch leaf parsley', 114),
#  ('soy milk', 113),
#  ('rings', 113),
#  ('vegan topping', 112),
#  ('chocolate', 111),
#  ('dry', 111),
#  ('oyster sauce', 110),
#  ('orange liqueur', 110),
#  ('bite size', 109),
#  ('ghirardelli cacao bittersweet chocolate chips', 109),
#  ('tequila', 108),
#  ('vanilla', 106),
#  ('teriyaki sauce', 106),
#  ('tahini', 106),
#  ('burgundy wine', 105),
#  ('oranges', 105),
#  ('package extra firm tofu', 105),
#  ('lime zest', 104),
#  ('whole tomatoes', 103),
#  ('chicken wings', 103),
#  ('goat cheese', 102),
#  ('whipping cream', 102),
#  ('mango juice', 101),
#  ('kale', 101),
#  ('pasta', 100),
#  ('sprigs thyme', 100),
#  ('granules', 99),
#  ('grape tomatoes', 99),
#  ('green olives', 99),
#  ('beets', 99),
#  ('peas', 97),
#  ('chile peppers', 97),
#  ('bean sprouts', 97),
#  ('agave nectar', 96),
#  ('salad', 95),
#  ('chipotle chile adobo sauce', 95),
#  ('lemon lime beverage', 95),
#  ('cornflakes cereal', 95),
#  ('date syrup', 95),
#  ('chicken thighs', 95),
#  ('leeks', 95),
#  ('currants', 95),
#  ('granny smith apple', 94),
#  ('whole chilies', 94),
#  ('custard powder', 93),
#  ('scallions', 93),
#  ('salmon', 92),
#  ('seafood', 91),
#  ('light cream', 91),
#  ('naval oranges', 91),
#  ('chive dressing', 90),
#  ('frosting', 90),
#  ('beef stock', 90),
#  ('cinnamon sticks', 90),
#  ('bag spinach', 89),
#  ('dark rum', 89),
#  ('salmon fillets', 89),
#  ('hazelnuts', 89),
#  ('sauerkraut', 88),
#  ('cooking oil', 87),
#  ('golden corn', 87),
#  ('bag lettuce', 86),
#  ('package elbow macaroni', 86),
#  ('cream style corn', 86),
#  ('lentils', 86),
#  ('scallops', 86),
#  ('hoisin sauce', 85),
#  ('limeade concentrate', 85),
#  ('almond flour', 85),
#  ('ice cold water', 84),
#  ('rice flour', 84),
#  ('pineapple with juice', 83),
#  ('old oats', 83),
#  ('pears', 82),
#  ('peppers', 82),
#  ('brussels sprouts', 82),
#  ('melon', 81),
#  ('flax seeds', 81),
#  ('syrup', 80),
#  ('superfine sugar', 80),
#  ('butterscotch chips', 80),
#  ('macaroni', 79),
#  ('leek', 79),
#  ('long grain rice', 78),
#  ('cubes beef bouillon', 78),
#  ('prosciutto', 78),
#  ('jars with lids', 78),
#  ('black peppercorns', 78),
#  ('triple sec', 77),
#  ('mexican cheese blend', 77),
#  ('barbecue sauce', 77),
#  ('fennel', 77),
#  ('frozen blueberries', 77),
#  ('sherry', 77),
#  ('rotini pasta', 76),
#  ('basmati rice', 76),
#  ('low milk', 76),
#  ('ears corn', 76),
#  ('ground almonds', 76),
#  ('fruit for dipping strawberries', 76),
#  ('tomato salsa', 75),
#  ('jack cheese', 75),
#  ('fruit', 75),
#  ('for soy sauce', 74),
#  ('wheat bran', 74),
#  ('chicken breast', 74),
#  ('wild rice', 73),
#  ('steak sauce', 73),
#  ('wesson oil', 73),
#  ('radishes', 72),
#  ('toothpicks', 72),
#  ('whiskey', 72),
#  ('bunch parsley', 72),
#  ('cheese', 71),
#  ('vegetable stock', 71),
#  ('sprigs rosemary', 71),
#  ('mirin', 70),
#  ('french onions', 70),
#  ('vanilla yogurt', 70),
#  ('ground lamb', 69),
#  ('mango puree', 69),
#  ('glaze', 69),
#  ('tortilla chips', 69),
#  ('lard', 68),
#  ('marmalade', 68),
#  ('coffee powder', 68),
#  ('caraway seeds', 68),
#  ('rice crackers', 68),
#  ('chili sauce', 67),
#  ('cola beverage', 67),
#  ('bunch leaf kale', 67),
#  ('beef', 67),
#  ('rhubarb soda', 66),
#  ('strong coffee', 66),
#  ('chickpeas', 66),
#  ('pecan bits', 66),
#  ('mint extract', 66),
#  ('italian parsley', 66),
#  ('orzo pasta', 65),
#  ('ginger ale', 65),
#  ('flank steak', 65),
#  ('almond butter', 65),
#  ('kamut flour', 65),
#  ('coarse salt', 65),
#  ('sandwich bread', 64),
#  ('butter shortening', 64),
#  ('kirsch liqueur', 64),
#  ('jar pimento peppers', 64),
#  ('choy', 64),
#  ('pizza sauce', 63),
#  ('gorgonzola cheese', 63),
#  ('gruyere cheese', 63),
#  ('asiago cheese', 63),
#  ('fine cornmeal', 63),
#  ('yakisoba noodles', 63),
#  ('lettuce leaves', 63),
#  ('containers vanilla greek yogurt', 63),
#  ('arugula', 62),
#  ('ground mace', 62),
#  ('coffee', 62),
#  ('parsley flakes', 62),
#  ('dry yellow lentils', 62),
#  ('black walnut extract', 62),
#  ('chuck roast', 62),
#  ('arborio rice', 61),
#  ('pepperoni', 61),
#  ('ground chicken', 61),
#  ('amaretto liqueur', 61),
#  ('skewers', 61),
#  ('cauliflower florets', 61),
#  ('wheat bread', 60),
#  ('cube ice', 60),
#  ('parsley paste', 60),
#  ('whole turkey', 60),
#  ('tomatoes with juice', 59),
#  ('polish sausage', 59),
#  ('eggnog', 59),
#  ('snow peas', 59),
#  ('pickles', 59),
#  ('tomatillos', 59),
#  ('tilapia fillets', 59)]

# %%
names, counts = zip(*order(combined_ingredients))
sorted(names[:200])
# Out:
# ['almonds',
#  'anise oil',
#  'apple',
#  'apple pie spice',
#  'apples',
#  'avocado',
#  'bacon',
#  'baking soda',
#  'balsamic vinegar',
#  'banana',
#  'banana extract',
#  'bananas',
#  'barberries',
#  'basil',
#  'bay leaf',
#  'bay powder',
#  'beans',
#  'beef broth',
#  'beer',
#  'bell pepper',
#  'berries',
#  'black beans',
#  'black olives',
#  'black pepper',
#  'blackberries',
#  'boiling water',
#  'broccoli',
#  'brownie crust',
#  'bulgar',
#  'butter',
#  'buttermilk',
#  'cabbage',
#  'carob powder',
#  'carrot',
#  'carrots',
#  'cayenne pepper',
#  'celery',
#  'champagne vinegar',
#  'cheddar cheese',
#  'chicken',
#  'chicken broth',
#  'chicken stock',
#  'chili powder',
#  'chives',
#  'chunks potatoes',
#  'cider vinegar',
#  'cilantro',
#  'cinnamon',
#  'cloves garlic',
#  'cocoa powder',
#  'coconut',
#  'cold vinegar',
#  'confectioners sugar',
#  'container sour cream',
#  'core',
#  'corn sugar',
#  'cornstarch',
#  'cream',
#  'cream tartar',
#  'cucumber',
#  'cut',
#  'dijon mustard',
#  'dill',
#  'dole white',
#  'dry bread crumbs',
#  'dry yeast',
#  'eagle milk',
#  'edam cheese',
#  'egg',
#  'eggs',
#  'filling',
#  'flour tortillas',
#  'garlic',
#  'garlic cloves',
#  'ginger',
#  'ginger root',
#  'gluten multi purpose flour',
#  'goat milk',
#  'goya wine vinegar',
#  'green onion',
#  'green onions',
#  'ground allspice',
#  'ground beef',
#  'ground black pepper',
#  'ground cumin',
#  'ground ginger',
#  'ground nutmeg',
#  'ham',
#  'honey',
#  'hot sauce',
#  'hot water',
#  'ice',
#  'ice cubes',
#  'jumbo chocolate chips',
#  'kelp flakes',
#  'ketchup',
#  'kosher salt',
#  'lemon',
#  'lemon juice',
#  'lemon zest',
#  'lime',
#  'lime juice',
#  'margarine',
#  'marshmallows',
#  'masa flour',
#  'mayonnaise',
#  'meal',
#  'meringue powder',
#  'miami style cuban seasoning',
#  'milk',
#  'molasses',
#  'monterey jack cheese',
#  'mozzarella cheese',
#  'mushrooms',
#  'mustard',
#  'nuts',
#  'oats',
#  'oil',
#  'onion',
#  'onion powder',
#  'onions',
#  'orange',
#  'orange juice',
#  'orange zest',
#  'oregano',
#  'package frozen spinach',
#  'package mushrooms',
#  'pancake syrup',
#  'paprika',
#  'parmesan cheese',
#  'parsley',
#  'pastry cream',
#  'peanut butter',
#  'pecans',
#  'pepper',
#  'pickle juice',
#  'plain yogurt',
#  'poblano peppers',
#  'potatoes',
#  'pumpkin puree',
#  'quick cooking oats',
#  'quinoa',
#  'raisins',
#  'rosemary',
#  'safflower',
#  'sage',
#  'salsa',
#  'salt',
#  'sauce',
#  'serrano pepper',
#  'sesame oil',
#  'sesame seeds',
#  'shallots',
#  'shortening',
#  'shrimp',
#  'skim milk',
#  'skinless',
#  'sorrel leaves',
#  'sour cream',
#  'spicy beans',
#  'spinach',
#  'stalk celery',
#  'stalks celery',
#  'sweet onion',
#  'swiss cheese',
#  'tabasco pepper sauce',
#  'thyme',
#  'tomato',
#  'tomato paste',
#  'tomato sauce',
#  'tomatoes',
#  'tonic water',
#  'turmeric',
#  'tuscan olive oil',
#  'vegetable broth',
#  'vegetable oil',
#  'vegetable oil for frying',
#  'vegetarian beans',
#  'vinegar',
#  'vodka',
#  'walnut oil',
#  'walnuts',
#  'warm water',
#  'water',
#  'wheat flour',
#  'white onion',
#  'white pepper',
#  'white rice',
#  'white sugar',
#  'white wine',
#  'whites',
#  'whole chicken',
#  'wine',
#  'worcestershire sauce',
#  'yellow leaves',
#  'yellow mustard',
#  'yellow onion',
#  'yolk',
#  'yolks',
#  'zucchini']

# %%
# COMBINE SIMILAR AGAIN, but this time with higher ratio 0.9 to get rid of plurals

sorted(order(combine_similar(dict(order(combined_ingredients)[:200]), ratio=0.9, combine_reverse=False)))
# Out:
# [('almonds', 804),
#  ('anise oil', 5714),
#  ('apple', 1285),
#  ('apple pie spice', 233),
#  ('avocado', 321),
#  ('bacon', 1251),
#  ('baking soda', 3034),
#  ('balsamic vinegar', 621),
#  ('banana', 728),
#  ('banana extract', 456),
#  ('barberries', 575),
#  ('basil', 1462),
#  ('bay leaf', 434),
#  ('bay powder', 524),
#  ('beans', 402),
#  ('beef broth', 305),
#  ('beer', 231),
#  ('bell pepper', 2765),
#  ('berries', 395),
#  ('black beans', 412),
#  ('black olives', 392),
#  ('black pepper', 961),
#  ('blackberries', 571),
#  ('boiling water', 521),
#  ('broccoli', 251),
#  ('brownie crust', 231),
#  ('bulgar', 836),
#  ('butter', 12443),
#  ('buttermilk', 609),
#  ('cabbage', 514),
#  ('carob powder', 2206),
#  ('carrot', 2357),
#  ('cayenne pepper', 1404),
#  ('celery', 1019),
#  ('champagne vinegar', 511),
#  ('cheddar cheese', 1733),
#  ('chicken', 306),
#  ('chicken broth', 1333),
#  ('chicken stock', 443),
#  ('chili powder', 1071),
#  ('chives', 316),
#  ('chunks potatoes', 323),
#  ('cider vinegar', 309),
#  ('cilantro', 1424),
#  ('cinnamon', 3991),
#  ('cloves garlic', 4734),
#  ('cocoa powder', 971),
#  ('coconut', 894),
#  ('cold vinegar', 283),
#  ('confectioners sugar', 1742),
#  ('container sour cream', 269),
#  ('core', 2681),
#  ('corn sugar', 4006),
#  ('cornstarch', 1216),
#  ('cream', 408),
#  ('cream tartar', 310),
#  ('cucumber', 394),
#  ('cut', 387),
#  ('dijon mustard', 568),
#  ('dill', 572),
#  ('dole white', 251),
#  ('dry bread crumbs', 366),
#  ('dry yeast', 326),
#  ('eagle milk', 345),
#  ('edam cheese', 392),
#  ('egg', 3026),
#  ('eggs', 6834),
#  ('filling', 230),
#  ('flour tortillas', 318),
#  ('garlic', 1790),
#  ('garlic cloves', 925),
#  ('ginger', 567),
#  ('ginger root', 563),
#  ('gluten multi purpose flour', 8784),
#  ('goat milk', 391),
#  ('goya wine vinegar', 235),
#  ('green onion', 1837),
#  ('ground allspice', 459),
#  ('ground beef', 1015),
#  ('ground black pepper', 7953),
#  ('ground cumin', 1412),
#  ('ground ginger', 961),
#  ('ground nutmeg', 1625),
#  ('ham', 406),
#  ('honey', 1658),
#  ('hot sauce', 233),
#  ('hot water', 342),
#  ('ice', 332),
#  ('ice cubes', 397),
#  ('jumbo chocolate chips', 743),
#  ('kelp flakes', 1041),
#  ('ketchup', 788),
#  ('kosher salt', 818),
#  ('lemon', 937),
#  ('lemon juice', 2765),
#  ('lemon zest', 553),
#  ('lime', 509),
#  ('lime juice', 874),
#  ('margarine', 1175),
#  ('marshmallows', 232),
#  ('masa flour', 316),
#  ('mayonnaise', 1604),
#  ('meal', 265),
#  ('meringue powder', 3202),
#  ('miami style cuban seasoning', 437),
#  ('milk', 6125),
#  ('molasses', 338),
#  ('monterey jack cheese', 300),
#  ('mozzarella cheese', 849),
#  ('mushrooms', 1152),
#  ('mustard', 390),
#  ('nuts', 290),
#  ('oats', 664),
#  ('oil', 676),
#  ('onion', 9152),
#  ('onion powder', 768),
#  ('orange', 257),
#  ('orange juice', 895),
#  ('orange zest', 373),
#  ('oregano', 1561),
#  ('package frozen spinach', 256),
#  ('package mushrooms', 231),
#  ('pancake syrup', 401),
#  ('paprika', 1373),
#  ('parmesan cheese', 2195),
#  ('parsley', 2080),
#  ('pastry cream', 951),
#  ('peanut butter', 544),
#  ('pecans', 1177),
#  ('pepper', 3218),
#  ('pickle juice', 290),
#  ('plain yogurt', 301),
#  ('poblano peppers', 414),
#  ('potatoes', 1492),
#  ('pumpkin puree', 394),
#  ('quick cooking oats', 323),
#  ('quinoa', 235),
#  ('raisins', 968),
#  ('rosemary', 643),
#  ('safflower', 244),
#  ('sage', 405),
#  ('salsa', 282),
#  ('salt', 19993),
#  ('sauce', 465),
#  ('serrano pepper', 518),
#  ('sesame oil', 586),
#  ('sesame seeds', 398),
#  ('shallots', 250),
#  ('shortening', 1067),
#  ('shrimp', 599),
#  ('skim milk', 260),
#  ('skinless', 1758),
#  ('sorrel leaves', 285),
#  ('sour cream', 1645),
#  ('spicy beans', 256),
#  ('spinach', 374),
#  ('stalks celery', 1013),
#  ('sweet onion', 347),
#  ('swiss cheese', 315),
#  ('tabasco pepper sauce', 650),
#  ('thyme', 955),
#  ('tomato', 735),
#  ('tomato paste', 636),
#  ('tomato sauce', 752),
#  ('tomatoes', 1742),
#  ('tonic water', 528),
#  ('turmeric', 418),
#  ('tuscan olive oil', 1000),
#  ('vegetable broth', 305),
#  ('vegetable oil', 4090),
#  ('vegetable oil for frying', 399),
#  ('vegetarian beans', 315),
#  ('vinegar', 235),
#  ('vodka', 228),
#  ('walnut oil', 294),
#  ('walnuts', 1615),
#  ('warm water', 568),
#  ('water', 6829),
#  ('wheat flour', 489),
#  ('white onion', 284),
#  ('white pepper', 375),
#  ('white rice', 388),
#  ('white sugar', 11129),
#  ('white wine', 479),
#  ('whites', 692),
#  ('whole chicken', 261),
#  ('wine', 275),
#  ('worcestershire sauce', 1286),
#  ('yellow leaves', 408),
#  ('yellow mustard', 273),
#  ('yellow onion', 460),
#  ('yolk', 270),
#  ('yolks', 619),
#  ('zucchini', 806)]

# %%
re.split(r"\band\b|\bor\b|\bplus\b", "oregano and oranges andrew")
# Out:
# ['oregano ', ' oranges andrew']

# %%
"Ω" < "s"
# Out:
# False
