# %%
import pandas as pd

# %%
data_root = "recipebox"

# %%
from glob import glob
datasets = glob(data_root + "/recipes*.json")
datasets = datasets[1], datasets[0], datasets[2]

# %%
stoppers = (",", ";") # stop reading the string here

measure_words = (
    # from https://en.wikipedia.org/wiki/Cooking_weights_and_measures#United_States_measures
    "scant",
    "drop",
    "smidgen",
    "pinch",
    "dash",
    "head",
    "piece",
    "splash",
    "squeeze",
    # from # from https://en.wikibooks.org/wiki/Cookbook:Units_of_measurement
    # fluid
    "teaspoon","t", "tsp",
    "tablespoon", "T", "tbl", "tbs", "tbsp", 
    "fluid ounce", "fl oz",
    "gill",
    "cup", "c",
    "pint", "p", "pt", "fl pt",
    "quart", "q", "qt", "fl qt",
    "gallon", "g", "gal",
    "ml", "milliliter", "millilitre", "cc",
    "l", "liter", "litre",
    "dl", "deciliter", "decilitre",
    "can",
    "bottle",
    # weight
    "pound", "lb" "#",
    "ounce", "oz",
    "mg", "milligram", "milligramme",
    "g", "gram", "gramme",
    "kg", "kilogram", "kilogramme",
    # length
    "mm", "millimeter", "millimetre",
    "cm", "centimeter", "centimetre",
    "m", "meter", "metre",
    "inch", "in",
    # size
    "large",
    "medium",
    "small",
    "about",
    # quantifiers
    "half",
    "single",
    "couple",
    "dozen",
    "many",
    "each",
    "some",
    "every",
    "pair",
    "additional",
    "approx".
    "more",
    "less",
    # misc
    "bag",
    "box",
    "bunch",
    "handful",
    "slice",
    "end",
    "accompaniment"
)


adjective_endings = ("ly",) # remove any word that ends with this
verb_endings = ("ed",) # e.g. packed, melted, chopped, chilled, divided, trimmed, grated
endings = verb_endings + adjective_endings
endings

to_remove = (
    "advertisement", 
    "of", "a", "the", "an",
    "to", "about", "from", "at", "by", "as", "above", "below", "abs",
    "recipe",
    "favorite", "choice", 
    "fat", "free", "taste", "garnish",
    "baby", "plump", "pure", "simple", "fresh", "torn", "good", "quality", "brand", "new", "dusting",
    "very",
    
)
cardinal_numbers = ("one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen", "sixteen", "seventeen", "eighteen", "nineteen", "twenty")

# %%
import re

def lower(string):
    return string.lower()

def remove_after_stopper(string):
    # remove after any comma, colon, or period
    return re.sub(r"[,;\.].*", "", string)

def remove_between_paren(string):
    # \( and \) for parentheses characters
    return re.sub(r"\(.*\)", "", string)

def remove_measure_words(string):
    for m in measure_words:
        # greater than 1, don't want to apply to single letters. E.g. c for cups
        if len(m) > 1:
            # \b word boundary, %s the measure word, [a-zA-Z]* any number of following letters, \b word boundary
            string = re.sub(r"\b%s[a-zA-z]*\b" %m, "", string)
        else:
            string = re.sub(r"\b%s\b" %m, "", string)
    return string

def remove_nonalpha(string):
    # first replace dashes with spaces
    string = string.replace("-", " ")
    # ^ not, [a-zA-z] letter, \s space
    return re.sub(r"[^a-zA-Z\s]", "", string)

def remove_endings(string):
    for end in endings:
        string = re.sub(r"\b[\w]+%s\b" %end, "", string)
    return string

def remove_less_than(num):
    def remove_less_than_from_str(string):
        # remove words with less than num letters
        return re.sub(r"\b[\w]{%s}\b" % ",".join(str(i) for i in range(1,num+1)), "", string)
    return remove_less_than_from_str

def remove_dumb_words(string):
    for word in to_remove + cardinal_numbers:
        string = re.sub(r"\b%s\b" % word, "", string)
    return string

def remove_available_at(string):
    """ remove 'available at *** markets' """
    return re.sub(r"available at.*markets", "", string)

def remove_extra_spaces(string):
    return re.sub(r"\s+", " ", string)

def strip(string):
    return string.strip()

import functools
def compose(*functions):
    # we have to reverse to get in the desired order
    functions = reversed(functions)
    return functools.reduce(lambda f, g: lambda x: f(g(x)), functions, lambda x: x)

functions = (
    lower,
    remove_after_stopper, 
    remove_between_paren, 
    remove_measure_words, 
    remove_nonalpha, 
    remove_endings,
    remove_less_than(2),
    remove_dumb_words,
    remove_available_at,
    remove_extra_spaces, 
    strip
)
extract_ingredient = compose(*functions)

# %%
re.split("and|or", "tomatoes and potatos")
# Out:
# ['tomatoes ', ' potatos']

# %%
from tqdm import tqdm_notebook as tqdm
from collections import defaultdict
import numpy as np

ingredients = defaultdict(int)

for ds in tqdm(datasets, desc="Dataset"):
    print("Loading dataset", ds)
    df = pd.read_json(ds)
    all_ingredient_lists = df.loc["ingredients"]
    for ingredient_list in tqdm(all_ingredient_lists, desc="recipes"):
        try:
            if type(ingredient_list) != list:
                continue
            for ingredient_string in ingredient_list:
                
                # SPLIT THE INGREDIENT STRING ON AND AND OR
                parts = re.split(r"\band\b|\bor\b|\bplus\b", ingredient_string)
                if len(parts) > 1:
                    ingredient_list += parts[1:]
                    ingredient_string = parts[0]
                
                ingredient = extract_ingredient(ingredient_string)
                if ingredient: # ignore empty string
                    ingredients[ingredient] += 1
        except Exception as e:
            print(f"Warning! failed on {str(ingredient_list)}")
            print(e)
# Out:
# HBox(children=(IntProgress(value=0, description='Dataset', max=3, style=ProgressStyle(description_width='initi…
# Loading dataset recipebox/recipes_raw_nosource_ar.json
# HBox(children=(IntProgress(value=0, description='recipes', max=39802, style=ProgressStyle(description_width='i…
# Loading dataset recipebox/recipes_raw_nosource_epi.json
# HBox(children=(IntProgress(value=0, description='recipes', max=25323, style=ProgressStyle(description_width='i…
# Loading dataset recipebox/recipes_raw_nosource_fn.json
# HBox(children=(IntProgress(value=0, description='recipes', max=60039, style=ProgressStyle(description_width='i…

# %%
def order(my_dict):
    return sorted(my_dict.items(), key=lambda x:x[1], reverse=True)

# %%
len(ingredients)
# Out:
# 74947

# %%
order(ingredients)[:200]
# Out:
# [('salt', 54826),
#  ('butter', 37722),
#  ('ground black pepper', 29544),
#  ('sugar', 27418),
#  ('olive oil', 23372),
#  ('all purpose flour', 22828),
#  ('kosher salt', 22679),
#  ('onion', 22056),
#  ('eggs', 17918),
#  ('water', 17244),
#  ('cloves garlic', 14603),
#  ('vanilla extract', 13162),
#  ('extra virgin olive oil', 13056),
#  ('vegetable oil', 12092),
#  ('milk', 11713),
#  ('lemon juice', 11639),
#  ('white sugar', 11355),
#  ('pepper', 10548),
#  ('ground cinnamon', 7994),
#  ('baking powder', 7810),
#  ('heavy cream', 7595),
#  ('egg', 7554),
#  ('garlic', 7469),
#  ('brown sugar', 6789),
#  ('garlic cloves', 6355),
#  ('honey', 6259),
#  ('baking soda', 6250),
#  ('oil', 6173),
#  ('parsley', 6010),
#  ('black pepper', 5623),
#  ('carrots', 5423),
#  ('ginger', 5231),
#  ('sour cream', 5198),
#  ('more', 4896),
#  ('mayonnaise', 4848),
#  ('lime juice', 4837),
#  ('ground cumin', 4768),
#  ('ground pepper', 4704),
#  ('onions', 4640),
#  ('tomatoes', 4600),
#  ('lemon', 4582),
#  ('clove garlic', 4550),
#  ('cilantro', 4423),
#  ('confectioners sugar', 4306),
#  ('oregano', 4249),
#  ('soy sauce', 4132),
#  ('cayenne pepper', 4126),
#  ('dijon mustard', 3992),
#  ('thyme', 3930),
#  ('parmesan cheese', 3858),
#  ('paprika', 3785),
#  ('bell pepper', 3706),
#  ('garlic powder', 3683),
#  ('cornstarch', 3605),
#  ('chicken stock', 3595),
#  ('pepper flakes', 3552),
#  ('egg yolks', 3541),
#  ('whole milk', 3513),
#  ('shallots', 3473),
#  ('worcestershire sauce', 3415),
#  ('scallions', 3354),
#  ('basil', 3350),
#  ('wine vinegar', 3341),
#  ('chives', 3281),
#  ('walnuts', 3227),
#  ('parmesan', 3199),
#  ('orange juice', 3197),
#  ('bacon', 3171),
#  ('chicken broth', 3045),
#  ('light brown sugar', 3000),
#  ('dry white wine', 2986),
#  ('flour', 2959),
#  ('green onions', 2872),
#  ('potatoes', 2863),
#  ('ground nutmeg', 2858),
#  ('basil leaves', 2758),
#  ('sea salt', 2727),
#  ('almonds', 2656),
#  ('lemon zest', 2651),
#  ('carrot', 2647),
#  ('stick butter', 2646),
#  ('pecans', 2638),
#  ('balsamic vinegar', 2616),
#  ('chili powder', 2607),
#  ('buttermilk', 2596),
#  ('egg whites', 2558),
#  ('green bell pepper', 2557),
#  ('shallot', 2545),
#  ('cilantro leaves', 2470),
#  ('bay leaves', 2411),
#  ('cocoa powder', 2323),
#  ('shrimp', 2316),
#  ('tomato paste', 2313),
#  ('flat leaf parsley', 2292),
#  ('celery', 2245),
#  ('garlic clove', 2235),
#  ('ground ginger', 2155),
#  ('zucchini', 2153),
#  ('skinless', 2139),
#  ('bay leaf', 2126),
#  ('cheddar cheese', 2095),
#  ('nutmeg', 2090),
#  ('white wine', 2017),
#  ('rosemary', 2006),
#  ('lime', 2001),
#  ('parsley leaves', 1999),
#  ('mushrooms', 1994),
#  ('cut', 1960),
#  ('dill', 1954),
#  ('ketchup', 1951),
#  ('coconut', 1913),
#  ('cream', 1907),
#  ('sesame oil', 1882),
#  ('strawberries', 1876),
#  ('yellow onion', 1859),
#  ('white vinegar', 1849),
#  ('white wine vinegar', 1818),
#  ('mint leaves', 1805),
#  ('cream cheese', 1803),
#  ('raisins', 1784),
#  ('ground beef', 1783),
#  ('tomato', 1765),
#  ('thyme leaves', 1742),
#  ('maple syrup', 1738),
#  ('hot sauce', 1712),
#  ('ground cloves', 1702),
#  ('dark brown sugar', 1668),
#  ('heavy whipping cream', 1571),
#  ('stalks celery', 1556),
#  ('onion powder', 1553),
#  ('capers', 1539),
#  ('margarine', 1510),
#  ('apple cider vinegar', 1486),
#  ('cinnamon', 1471),
#  ('chicken', 1470),
#  ('sprigs thyme', 1462),
#  ('orange', 1449),
#  ('ice cubes', 1445),
#  ('package cream cheese', 1443),
#  ('sticks butter', 1441),
#  ('cold water', 1440),
#  ('vanilla', 1435),
#  ('whipping cream', 1417),
#  ('coarse salt', 1416),
#  ('white onion', 1400),
#  ('warm water', 1378),
#  ('tomato sauce', 1365),
#  ('rice vinegar', 1364),
#  ('plum tomatoes', 1355),
#  ('ice', 1348),
#  ('orange zest', 1346),
#  ('mint', 1339),
#  ('ground allspice', 1337),
#  ('ground coriander', 1335),
#  ('spinach', 1334),
#  ('cooking spray', 1331),
#  ('cider vinegar', 1330),
#  ('sesame seeds', 1321),
#  ('cherry tomatoes', 1304),
#  ('mozzarella cheese', 1285),
#  ('cranberries', 1284),
#  ('pineapple', 1279),
#  ('egg yolk', 1259),
#  ('vanilla bean', 1259),
#  ('lemons', 1248),
#  ('curry powder', 1246),
#  ('juice lemon', 1246),
#  ('pine nuts', 1245),
#  ('peanut oil', 1244),
#  ('bell peppers', 1228),
#  ('semisweet chocolate chips', 1222),
#  ('shortening', 1222),
#  ('bread crumbs', 1198),
#  ('low sodium chicken broth', 1165),
#  ('sage', 1144),
#  ('blueberries', 1131),
#  ('ground white pepper', 1130),
#  ('black beans', 1123),
#  ('coconut milk', 1122),
#  ('cabbage', 1114),
#  ('light corn syrup', 1113),
#  ('beans', 1112),
#  ('raspberries', 1109),
#  ('almond extract', 1095),
#  ('wine', 1093),
#  ('hot pepper sauce', 1091),
#  ('semisweet chocolate', 1088),
#  ('cucumber', 1087),
#  ('cayenne', 1074),
#  ('boneless', 1058),
#  ('tarragon', 1046),
#  ('avocado', 1039),
#  ('arugula', 1035),
#  ('boiling water', 1034),
#  ('sweet potatoes', 1034),
#  ('brandy', 1033),
#  ('molasses', 1028),
#  ('russet potatoes', 1015),
#  ('limes', 1014),
#  ('cold butter', 1013)]

# %%
names, counts = zip(*order(ingredients))
sorted(names[:200])
# Out:
# ['all purpose flour',
#  'almond extract',
#  'almonds',
#  'apple cider vinegar',
#  'arugula',
#  'avocado',
#  'bacon',
#  'baking powder',
#  'baking soda',
#  'balsamic vinegar',
#  'basil',
#  'basil leaves',
#  'bay leaf',
#  'bay leaves',
#  'beans',
#  'bell pepper',
#  'bell peppers',
#  'black beans',
#  'black pepper',
#  'blueberries',
#  'boiling water',
#  'boneless',
#  'brandy',
#  'bread crumbs',
#  'brown sugar',
#  'butter',
#  'buttermilk',
#  'cabbage',
#  'capers',
#  'carrot',
#  'carrots',
#  'cayenne',
#  'cayenne pepper',
#  'celery',
#  'cheddar cheese',
#  'cherry tomatoes',
#  'chicken',
#  'chicken broth',
#  'chicken stock',
#  'chili powder',
#  'chives',
#  'cider vinegar',
#  'cilantro',
#  'cilantro leaves',
#  'cinnamon',
#  'clove garlic',
#  'cloves garlic',
#  'coarse salt',
#  'cocoa powder',
#  'coconut',
#  'coconut milk',
#  'cold butter',
#  'cold water',
#  'confectioners sugar',
#  'cooking spray',
#  'cornstarch',
#  'cranberries',
#  'cream',
#  'cream cheese',
#  'cucumber',
#  'curry powder',
#  'cut',
#  'dark brown sugar',
#  'dijon mustard',
#  'dill',
#  'dry white wine',
#  'egg',
#  'egg whites',
#  'egg yolk',
#  'egg yolks',
#  'eggs',
#  'extra virgin olive oil',
#  'flat leaf parsley',
#  'flour',
#  'garlic',
#  'garlic clove',
#  'garlic cloves',
#  'garlic powder',
#  'ginger',
#  'green bell pepper',
#  'green onions',
#  'ground allspice',
#  'ground beef',
#  'ground black pepper',
#  'ground cinnamon',
#  'ground cloves',
#  'ground coriander',
#  'ground cumin',
#  'ground ginger',
#  'ground nutmeg',
#  'ground pepper',
#  'ground white pepper',
#  'heavy cream',
#  'heavy whipping cream',
#  'honey',
#  'hot pepper sauce',
#  'hot sauce',
#  'ice',
#  'ice cubes',
#  'juice lemon',
#  'ketchup',
#  'kosher salt',
#  'lemon',
#  'lemon juice',
#  'lemon zest',
#  'lemons',
#  'light brown sugar',
#  'light corn syrup',
#  'lime',
#  'lime juice',
#  'limes',
#  'low sodium chicken broth',
#  'maple syrup',
#  'margarine',
#  'mayonnaise',
#  'milk',
#  'mint',
#  'mint leaves',
#  'molasses',
#  'more',
#  'mozzarella cheese',
#  'mushrooms',
#  'nutmeg',
#  'oil',
#  'olive oil',
#  'onion',
#  'onion powder',
#  'onions',
#  'orange',
#  'orange juice',
#  'orange zest',
#  'oregano',
#  'package cream cheese',
#  'paprika',
#  'parmesan',
#  'parmesan cheese',
#  'parsley',
#  'parsley leaves',
#  'peanut oil',
#  'pecans',
#  'pepper',
#  'pepper flakes',
#  'pine nuts',
#  'pineapple',
#  'plum tomatoes',
#  'potatoes',
#  'raisins',
#  'raspberries',
#  'rice vinegar',
#  'rosemary',
#  'russet potatoes',
#  'sage',
#  'salt',
#  'scallions',
#  'sea salt',
#  'semisweet chocolate',
#  'semisweet chocolate chips',
#  'sesame oil',
#  'sesame seeds',
#  'shallot',
#  'shallots',
#  'shortening',
#  'shrimp',
#  'skinless',
#  'sour cream',
#  'soy sauce',
#  'spinach',
#  'sprigs thyme',
#  'stalks celery',
#  'stick butter',
#  'sticks butter',
#  'strawberries',
#  'sugar',
#  'sweet potatoes',
#  'tarragon',
#  'thyme',
#  'thyme leaves',
#  'tomato',
#  'tomato paste',
#  'tomato sauce',
#  'tomatoes',
#  'vanilla',
#  'vanilla bean',
#  'vanilla extract',
#  'vegetable oil',
#  'walnuts',
#  'warm water',
#  'water',
#  'whipping cream',
#  'white onion',
#  'white sugar',
#  'white vinegar',
#  'white wine',
#  'white wine vinegar',
#  'whole milk',
#  'wine',
#  'wine vinegar',
#  'worcestershire sauce',
#  'yellow onion',
#  'zucchini']

# %%
from difflib import SequenceMatcher

def similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()


def combine_similar(my_dict, ratio=0.65, combine_reverse=True):
    """
    combines similar keys in the dictionary
    
    assumes the relevant similar parts are at the end of the key
    """
    new_dict = defaultdict(int)
    
    # we sort by the tail ends. puts tail ends next to each other. better similarity this way.
    # e.g. "awesome lemon zest" and "weird lemon zest" are typically far apart.
    # sorting from the ends puts them next to each other
    sorted_keys = sorted(my_dict, key=lambda x: x[::-1].replace(" ", "Ω") if combine_reverse else x.replace(" ", "Ω")) 
    prev = ""
    for k in sorted_keys:
        if similarity(prev, k) > ratio:
            new_dict[prev] = my_dict[prev] + my_dict[k]
        else:
            new_dict[k] = my_dict[k]
            prev = k
    return new_dict

# %%
combined_ingredients = combine_similar(ingredients)
len(combined_ingredients)
# Out:
# 37558

# %%
order(combined_ingredients)[:500]
# Out:
# [('salt', 54826),
#  ('butter', 37722),
#  ('bulgar', 27419),
#  ('olive oil', 23372),
#  ('kocher salt', 22680),
#  ('onion', 22056),
#  ('eggs', 17918),
#  ('water', 17244),
#  ('ounces garlic', 14604),
#  ('vegetable oil', 12093),
#  ('milk', 11713),
#  ('chocolate sugar', 11357),
#  ('pepper', 10548),
#  ('sri lanka cinnamon', 7995),
#  ('hot pastry cream', 7596),
#  ('egg', 7554),
#  ('garlic', 7470),
#  ('brown sugar', 6791),
#  ('garlic cloves', 6358),
#  ('honey', 6259),
#  ('baking soda', 6251),
#  ('oil', 6174),
#  ('pot barley', 6011),
#  ('carrots', 5423),
#  ('tomatoes', 5295),
#  ('ginger', 5277),
#  ('for cream', 5202),
#  ('more', 4897),
#  ('mayonnaise', 4850),
#  ('chipotle juice', 4838),
#  ('ground cumin', 4772),
#  ('onions', 4640),
#  ('emon', 4584),
#  ('brunoise garlic', 4551),
#  ('cilantro', 4423),
#  ('confectioners sugar', 4307),
#  ('oregano', 4249),
#  ('paprika', 3940),
#  ('thyme', 3930),
#  ('bell pepper', 3875),
#  ('parmesan cheese', 3859),
#  ('gold metallic powder', 3684),
#  ('starch', 3607),
#  ('chicken stock', 3598),
#  ('agar flakes', 3558),
#  ('homemade milk', 3517),
#  ('shallots', 3474),
#  ('worecestershire sauce', 3416),
#  ('scallions', 3354),
#  ('basil', 3350),
#  ('wine vinegar', 3342),
#  ('chives', 3281),
#  ('green onions', 3233),
#  ('walnuts', 3227),
#  ('parmesan', 3205),
#  ('bacon', 3171),
#  ('bean broth', 3046),
#  ('flour', 2959),
#  ('potatoes', 2876),
#  ('organic nutmeg', 2859),
#  ('betel leaves', 2760),
#  ('sea salt', 2727),
#  ('almonds', 2656),
#  ('more zest', 2653),
#  ('chili butter', 2647),
#  ('carrot', 2647),
#  ('pecans', 2638),
#  ('chili powder', 2625),
#  ('garlic vinegar', 2618),
#  ('buttermilk', 2597),
#  ('egg whites', 2560),
#  ('shallot', 2549),
#  ('parsley leaves', 2487),
#  ('taro leaves', 2473),
#  ('luau leaves', 2416),
#  ('celery', 2406),
#  ('cocoa powder', 2325),
#  ('shrimp', 2316),
#  ('tomato paste', 2314),
#  ('garlic clove', 2237),
#  ('zucchini', 2154),
#  ('skinless', 2140),
#  ('luau leaf', 2129),
#  ('cheddar cheese', 2096),
#  ('nutmeg', 2090),
#  ('semisweet chocolate', 2050),
#  ('rosemary', 2025),
#  ('white wine', 2017),
#  ('lime', 2002),
#  ('mushrooms', 1994),
#  ('cut', 1962),
#  ('dill', 1954),
#  ('ketchup', 1951),
#  ('coconut', 1914),
#  ('cream', 1907),
#  ('strawberries', 1891),
#  ('sesame oil', 1883),
#  ('white vinegar', 1850),
#  ('sprinkles rice wine vinegar', 1819),
#  ('mint leaves', 1814),
#  ('edam cheese', 1812),
#  ('maple syrup', 1805),
#  ('raisins', 1789),
#  ('ground beef', 1784),
#  ('mulato', 1767),
#  ('thyme leaves', 1750),
#  ('apricot sauce', 1713),
#  ('ground cloves', 1703),
#  ('dark brown sugar', 1669),
#  ('allspice', 1656),
#  ('sticks celery', 1564),
#  ('pectin powder', 1554),
#  ('capers', 1540),
#  ('margarine', 1511),
#  ('cinnamon', 1473),
#  ('chicken', 1471),
#  ('sprigs thyme', 1465),
#  ('range', 1457),
#  ('ice cubes', 1446),
#  ('ths butter', 1442),
#  ('cabbage', 1441),
#  ('vanilla', 1437),
#  ('white onion', 1431),
#  ('ice', 1418),
#  ('whipping cream', 1418),
#  ('coarse salt', 1416),
#  ('warm water', 1382),
#  ('rice vinegar', 1370),
#  ('miso sauce', 1367),
#  ('rind zest', 1347),
#  ('mint', 1339),
#  ('spinach', 1334),
#  ('serrano vinegar', 1331),
#  ('sesame seeds', 1323),
#  ('sage', 1317),
#  ('panela cheese', 1309),
#  ('yolk', 1298),
#  ('pineapple', 1281),
#  ('vanilla bean', 1264),
#  ('lemons', 1248),
#  ('nut oil', 1247),
#  ('bay powder', 1247),
#  ('juice lemon', 1246),
#  ('pine nuts', 1245),
#  ('turmeric', 1235),
#  ('shortening', 1231),
#  ('black peppers', 1229),
#  ('gooseberries', 1143),
#  ('nut milk', 1125),
#  ('molasses', 1122),
#  ('generous corn syrup', 1114),
#  ('beans', 1112),
#  ('salmonberries', 1111),
#  ('banana extract', 1109),
#  ('cayenne', 1106),
#  ('tabasco pepper sauce', 1101),
#  ('wine', 1097),
#  ('cucumber', 1088),
#  ('tarragon', 1069),
#  ('boneless', 1059),
#  ('avocado', 1039),
#  ('perfect potatoes', 1038),
#  ('fregula', 1036),
#  ('cooking water', 1035),
#  ('brandy', 1033),
#  ('nuts', 1027),
#  ('liquid butter', 1014),
#  ('limes', 1014),
#  ('cake flour', 996),
#  ('jalapeno', 988),
#  ('green beans', 978),
#  ('green tea ice cream', 972),
#  ('asian style sea salt', 944),
#  ('horseradish', 934),
#  ('apples', 931),
#  ('pan onion', 927),
#  ('sodium nonfat chicken broth', 916),
#  ('size white', 913),
#  ('caramel stick', 911),
#  ('whole cloves', 900),
#  ('cumin seeds', 894),
#  ('cream tartar', 891),
#  ('mozzarella', 885),
#  ('plain yogurt', 884),
#  ('vodka', 869),
#  ('white pepper', 868),
#  ('dark rum', 840),
#  ('lemon peel', 839),
#  ('ham', 833),
#  ('yukon gold potatoes', 829),
#  ('golden raisins', 819),
#  ('fenugreek seeds', 818),
#  ('flour tortillas', 815),
#  ('dry sherry', 791),
#  ('cornmeal', 790),
#  ('more for', 790),
#  ('mustard', 789),
#  ('fish sauce', 785),
#  ('peanut butter', 784),
#  ('garlic salt', 784),
#  ('barley wine', 783),
#  ('pickle juice', 771),
#  ('more for dusting', 769),
#  ('hot water', 768),
#  ('black olives', 764),
#  ('goat cheese', 763),
#  ('beef broth', 761),
#  ('bananas', 757),
#  ('bunch cilantro', 745),
#  ('well parsley', 740),
#  ('chinese rice', 739),
#  ('superfine sugar', 732),
#  ('cardamom', 731),
#  ('yellow bell pepper', 731),
#  ('thick celery', 727),
#  ('coriander seeds', 726),
#  ('vine tomatoes', 725),
#  ('rice', 718),
#  ('deli colby jack cheese', 710),
#  ('leeks', 710),
#  ('sauce', 704),
#  ('cheddar', 703),
#  ('carrot chunks', 700),
#  ('mango', 699),
#  ('apple', 695),
#  ('caribbean seasoning', 694),
#  ('frozen peas', 693),
#  ('sweet cubes', 691),
#  ('ground pork', 689),
#  ('bourbon', 689),
#  ('hot walnuts', 689),
#  ('vegetable broth', 687),
#  ('sunburst squash', 682),
#  ('cubano peppers', 681),
#  ('sweet onion', 669),
#  ('sage leaves', 667),
#  ('juice lime', 661),
#  ('apricots', 659),
#  ('cortlandmcintosh apples', 658),
#  ('walnut oil', 652),
#  ('rapid rise dry yeast', 644),
#  ('cherries', 637),
#  ('cauliflower', 633),
#  ('ice water', 632),
#  ('fennel', 628),
#  ('panquehue cheese', 626),
#  ('rindless cheese', 626),
#  ('branches rosemary', 626),
#  ('rosemary leaves', 624),
#  ('scallion', 623),
#  ('coarse ground black peppercorns', 621),
#  ('dry', 620),
#  ('egglant', 617),
#  ('cumin', 616),
#  ('peaches', 616),
#  ('hard eggs', 611),
#  ('orange peel', 610),
#  ('watermelon wedges', 607),
#  ('zest lemon', 602),
#  ('apple cider', 602),
#  ('lime wedges', 602),
#  ('pumpkin puree', 600),
#  ('chocolate', 596),
#  ('beer', 594),
#  ('pancetta', 592),
#  ('oranges', 591),
#  ('buratta cheese', 586),
#  ('vegetable stock', 585),
#  ('key', 585),
#  ('scallops', 583),
#  ('yellow cornmeal', 580),
#  ('asparagus', 580),
#  ('rosemary stalks', 578),
#  ('carrot dice', 574),
#  ('banana', 572),
#  ('cut thin sticks', 569),
#  ('white stock', 562),
#  ('salsa', 558),
#  ('creame peche', 558),
#  ('frozen', 557),
#  ('jalpenenos', 556),
#  ('yellow mustard', 553),
#  ('peppers', 547),
#  ('fennel bulb', 542),
#  ('new onions', 541),
#  ('vegetable oil for frying', 540),
#  ('syrup', 539),
#  ('gin', 535),
#  ('spaghetti', 533),
#  ('dishes', 528),
#  ('boboli', 524),
#  ('rum', 523),
#  ('romaine escarole lettuce', 518),
#  ('spanish onion', 517),
#  ('zest', 517),
#  ('vinegar', 516),
#  ('beets', 513),
#  ('papalo leaves', 507),
#  ('baguette', 504),
#  ('orange liqueur', 501),
#  ('sharp cheddar cheese', 499),
#  ('club soda', 497),
#  ('broth like chicken', 496),
#  ('majoram', 490),
#  ('orange tomatoes', 488),
#  ('spicy beans', 487),
#  ('apple pie spice', 486),
#  ('salmon', 482),
#  ('spinach leaves', 481),
#  ('blackberries', 480),
#  ('mexican white rice', 478),
#  ('dates', 477),
#  ('lime zest', 477),
#  ('corn', 476),
#  ('kinome sprigs', 476),
#  ('ripe tomatoes', 474),
#  ('more for drizzling', 472),
#  ('vegetable shortening', 470),
#  ('avocados', 467),
#  ('broccoli florets', 465),
#  ('bias celery', 465),
#  ('food coloring', 458),
#  ('quinoa', 455),
#  ('leek', 454),
#  ('hoisin sauce', 453),
#  ('iceberg lettuce', 452),
#  ('dry bread crumbs', 452),
#  ('tamarillos', 451),
#  ('currants', 443),
#  ('shakes paprika', 441),
#  ('leaves', 441),
#  ('mirin', 437),
#  ('mussels', 436),
#  ('pistachios', 431),
#  ('wild turkey', 429),
#  ('chickpeas', 426),
#  ('green parts', 426),
#  ('old oats', 425),
#  ('seeds', 424),
#  ('high chocolate chocolate', 422),
#  ('heaping scallions', 421),
#  ('heaping flour', 419),
#  ('cracker crumbs', 419),
#  ('mead', 417),
#  ('parsnips', 417),
#  ('pumpkin', 415),
#  ('marshmallows', 415),
#  ('yellow squash', 413),
#  ('quick cooking oats', 412),
#  ('thick', 411),
#  ('scallion threads', 410),
#  ('green cabbage', 408),
#  ('tan olives', 403),
#  ('romano cheese', 402),
#  ('celery salt', 400),
#  ('size cucumber', 398),
#  ('lettuce', 397),
#  ('greens', 397),
#  ('open leaves', 396),
#  ('tequila', 395),
#  ('cognac', 392),
#  ('warm mushrooms', 392),
#  ('plum halves', 389),
#  ('granny smith apple', 388),
#  ('mint sprigs', 388),
#  ('vegetable oil chicken broth', 384),
#  ('anchovy fillets', 383),
#  ('caraway seeds', 379),
#  ('meat', 379),
#  ('creamy peanut butter', 377),
#  ('clam juice', 375),
#  ('chai masala', 371),
#  ('gelatin', 370),
#  ('type sea salt', 370),
#  ('elk steak', 365),
#  ('white bread', 362),
#  ('lard', 360),
#  ('coriander', 359),
#  ('cloves', 358),
#  ('champagne', 356),
#  ('jalapeno cheddar', 356),
#  ('for pan', 355),
#  ('cucumbers', 355),
#  ('white grain rice', 354),
#  ('miso powder', 354),
#  ('crumbs', 354),
#  ('brussels sprouts', 354),
#  ('agave nectar', 353),
#  ('vegetable', 351),
#  ('organic cayenne pepper', 351),
#  ('ground porcini mushrooms', 351),
#  ('bittersweet', 351),
#  ('any seeds', 350),
#  ('spice hunter curry seasoning', 349),
#  ('bananas foster sauce', 346),
#  ('peas', 345),
#  ('celery ribs', 345),
#  ('whole almonds', 344),
#  ('chicken wings', 344),
#  ('couscous', 344),
#  ('cashews', 343),
#  ('baking potatoes', 341),
#  ('sprig rosemary', 341),
#  ('white', 338),
#  ('apple vinegar', 338),
#  ('sprig thyme', 336),
#  ('stems', 334),
#  ('gruyere cheese', 333),
#  ('asiago cheese', 333),
#  ('green', 333),
#  ('bliss potato', 331),
#  ('juice', 327),
#  ('green pepper', 327),
#  ('panko breadcrumbs', 327),
#  ('spice powder', 326),
#  ('cucumber sour cream', 325),
#  ('non oil', 324),
#  ('lump crabmeat', 323),
#  ('sazon seasoning', 322),
#  ('lengthwise', 321),
#  ('sweet', 321),
#  ('pork', 318),
#  ('whole eggs', 318),
#  ('extra for brushing', 317),
#  ('juice limes', 317),
#  ('frache', 316),
#  ('mustard seeds', 315),
#  ('tenderloin fillets', 315),
#  ('skim milk', 314),
#  ('rosemary stalk', 313),
#  ('pears', 313),
#  ('figs', 312),
#  ('eggplants', 312),
#  ('snow peas', 310),
#  ('garbanzo beans', 310),
#  ('star anise', 309),
#  ('dark chocolate', 306),
#  ('dry vermouth', 304),
#  ('celery juice', 302),
#  ('tahini', 302),
#  ('seedless grapes', 302),
#  ('deli cut bacon', 301),
#  ('nameko mushrooms', 301),
#  ('new potatoes', 300),
#  ('brown rice', 297),
#  ('kale', 297),
#  ('snap peas', 296),
#  ('szechuan chiles', 295),
#  ('radicchio', 294),
#  ('sprig parsley leaves', 294),
#  ('feta', 293),
#  ('saffron', 293),
#  ('potato', 293),
#  ('ultra eggs', 292),
#  ('oaxacan cheese', 291),
#  ('basmati rice', 290),
#  ('sherry', 289),
#  ('twist macaroni', 288),
#  ('anko', 287),
#  ('rice flour', 287),
#  ('beef', 286),
#  ('barbecue sauce', 285),
#  ('bag frozen chestnuts', 285),
#  ('package linguine pasta', 284),
#  ('natural cooking spray', 283),
#  ('topping', 282),
#  ('strips bacon', 280),
#  ('jicama', 279),
#  ('tomato puree', 279),
#  ('provolone cheese', 279),
#  ('white mushrooms', 278),
#  ('bok choy', 277),
#  ('oil depth for frying', 275),
#  ('packageenoki mushrooms', 273),
#  ('seafood seasoning', 271),
#  ('ricotta', 270),
#  ('white beans', 268),
#  ('morello cherries', 267),
#  ('rhubarb', 266),
#  ('filling', 266),
#  ('licorice liqueur', 266),
#  ('sweet orange', 265),
#  ('jalapeo chiles', 265),
#  ('ground', 264),
#  ('marmalade', 264),
#  ('whole', 262),
#  ('reggiano cheese', 262),
#  ('peppercorns', 262),
#  ('greek yogurt', 262),
#  ('float rum', 261),
#  ('coffee', 260),
#  ('tulips', 259),
#  ('nut', 259),
#  ('barbeque sauce', 258),
#  ('melon', 258),
#  ('grapefruit wedges', 257),
#  ('lentils', 257),
#  ('ground lamb', 256),
#  ('chile flakes', 255),
#  ('chokes', 254)]

# %%
names, counts = zip(*order(combined_ingredients))
sorted(names[:200])
# Out:
# ['agar flakes',
#  'allspice',
#  'almonds',
#  'apples',
#  'apricot sauce',
#  'asian style sea salt',
#  'avocado',
#  'bacon',
#  'baking soda',
#  'banana extract',
#  'basil',
#  'bay powder',
#  'bean broth',
#  'beans',
#  'bell pepper',
#  'betel leaves',
#  'black peppers',
#  'boneless',
#  'brandy',
#  'brown sugar',
#  'brunoise garlic',
#  'bulgar',
#  'butter',
#  'buttermilk',
#  'cabbage',
#  'cake flour',
#  'capers',
#  'caramel stick',
#  'carrot',
#  'carrots',
#  'cayenne',
#  'celery',
#  'cheddar cheese',
#  'chicken',
#  'chicken stock',
#  'chili butter',
#  'chili powder',
#  'chipotle juice',
#  'chives',
#  'chocolate sugar',
#  'cilantro',
#  'cinnamon',
#  'coarse salt',
#  'cocoa powder',
#  'coconut',
#  'confectioners sugar',
#  'cooking water',
#  'cornmeal',
#  'cream',
#  'cream tartar',
#  'cucumber',
#  'cumin seeds',
#  'cut',
#  'dark brown sugar',
#  'dark rum',
#  'dill',
#  'dry sherry',
#  'edam cheese',
#  'egg',
#  'egg whites',
#  'eggs',
#  'emon',
#  'fenugreek seeds',
#  'fish sauce',
#  'flour',
#  'flour tortillas',
#  'for cream',
#  'fregula',
#  'garlic',
#  'garlic clove',
#  'garlic cloves',
#  'garlic salt',
#  'garlic vinegar',
#  'generous corn syrup',
#  'ginger',
#  'gold metallic powder',
#  'golden raisins',
#  'gooseberries',
#  'green beans',
#  'green onions',
#  'green tea ice cream',
#  'ground beef',
#  'ground cloves',
#  'ground cumin',
#  'ham',
#  'homemade milk',
#  'honey',
#  'horseradish',
#  'hot pastry cream',
#  'ice',
#  'ice cubes',
#  'jalapeno',
#  'juice lemon',
#  'ketchup',
#  'kocher salt',
#  'lemon peel',
#  'lemons',
#  'lime',
#  'limes',
#  'liquid butter',
#  'luau leaf',
#  'luau leaves',
#  'maple syrup',
#  'margarine',
#  'mayonnaise',
#  'milk',
#  'mint',
#  'mint leaves',
#  'miso sauce',
#  'molasses',
#  'more',
#  'more for',
#  'more zest',
#  'mozzarella',
#  'mulato',
#  'mushrooms',
#  'mustard',
#  'nut milk',
#  'nut oil',
#  'nutmeg',
#  'nuts',
#  'oil',
#  'olive oil',
#  'onion',
#  'onions',
#  'oregano',
#  'organic nutmeg',
#  'ounces garlic',
#  'pan onion',
#  'panela cheese',
#  'paprika',
#  'parmesan',
#  'parmesan cheese',
#  'parsley leaves',
#  'peanut butter',
#  'pecans',
#  'pectin powder',
#  'pepper',
#  'perfect potatoes',
#  'pine nuts',
#  'pineapple',
#  'plain yogurt',
#  'pot barley',
#  'potatoes',
#  'raisins',
#  'range',
#  'rice vinegar',
#  'rind zest',
#  'rosemary',
#  'sage',
#  'salmonberries',
#  'salt',
#  'scallions',
#  'sea salt',
#  'semisweet chocolate',
#  'serrano vinegar',
#  'sesame oil',
#  'sesame seeds',
#  'shallot',
#  'shallots',
#  'shortening',
#  'shrimp',
#  'size white',
#  'skinless',
#  'sodium nonfat chicken broth',
#  'spinach',
#  'sprigs thyme',
#  'sprinkles rice wine vinegar',
#  'sri lanka cinnamon',
#  'starch',
#  'sticks celery',
#  'strawberries',
#  'tabasco pepper sauce',
#  'taro leaves',
#  'tarragon',
#  'ths butter',
#  'thyme',
#  'thyme leaves',
#  'tomato paste',
#  'tomatoes',
#  'turmeric',
#  'vanilla',
#  'vanilla bean',
#  'vegetable oil',
#  'vodka',
#  'walnuts',
#  'warm water',
#  'water',
#  'whipping cream',
#  'white onion',
#  'white pepper',
#  'white vinegar',
#  'white wine',
#  'whole cloves',
#  'wine',
#  'wine vinegar',
#  'worecestershire sauce',
#  'yolk',
#  'yukon gold potatoes',
#  'zucchini']

# %%
# COMBINE SIMILAR AGAIN, but this time with higher ratio 0.9 to get rid of plurals
refiltered = order(combine_similar(dict(order(combined_ingredients)[:500]), ratio=0.9, combine_reverse=False))
refiltered
# Out:
# [('salt', 54826),
#  ('butter', 37722),
#  ('bulgar', 27419),
#  ('onion', 26696),
#  ('olive oil', 23372),
#  ('kocher salt', 22680),
#  ('eggs', 17918),
#  ('water', 17244),
#  ('ounces garlic', 14604),
#  ('vegetable oil', 12093),
#  ('milk', 11713),
#  ('chocolate sugar', 11357),
#  ('pepper', 10548),
#  ('garlic clove', 8595),
#  ('carrot', 8070),
#  ('sri lanka cinnamon', 7995),
#  ('hot pastry cream', 7596),
#  ('egg', 7554),
#  ('garlic', 7470),
#  ('brown sugar', 6791),
#  ('honey', 6259),
#  ('baking soda', 6251),
#  ('oil', 6174),
#  ('shallot', 6023),
#  ('pot barley', 6011),
#  ('tomatoes', 5295),
#  ('ginger', 5277),
#  ('for cream', 5202),
#  ('more', 4897),
#  ('mayonnaise', 4850),
#  ('chipotle juice', 4838),
#  ('ground cumin', 4772),
#  ('emon', 4584),
#  ('brunoise garlic', 4551),
#  ('cilantro', 4423),
#  ('confectioners sugar', 4307),
#  ('oregano', 4249),
#  ('scallion', 3977),
#  ('paprika', 3940),
#  ('thyme', 3930),
#  ('bell pepper', 3875),
#  ('parmesan cheese', 3859),
#  ('gold metallic powder', 3684),
#  ('starch', 3607),
#  ('chicken stock', 3598),
#  ('agar flakes', 3558),
#  ('homemade milk', 3517),
#  ('worecestershire sauce', 3416),
#  ('basil', 3350),
#  ('wine vinegar', 3342),
#  ('chives', 3281),
#  ('green onions', 3233),
#  ('walnuts', 3227),
#  ('parmesan', 3205),
#  ('bacon', 3171),
#  ('bean broth', 3046),
#  ('flour', 2959),
#  ('potatoes', 2876),
#  ('organic nutmeg', 2859),
#  ('betel leaves', 2760),
#  ('sea salt', 2727),
#  ('almonds', 2656),
#  ('more zest', 2653),
#  ('chili butter', 2647),
#  ('pecans', 2638),
#  ('chili powder', 2625),
#  ('garlic vinegar', 2618),
#  ('buttermilk', 2597),
#  ('egg whites', 2560),
#  ('parsley leaves', 2487),
#  ('taro leaves', 2473),
#  ('luau leaves', 2416),
#  ('celery', 2406),
#  ('cocoa powder', 2325),
#  ('shrimp', 2316),
#  ('tomato paste', 2314),
#  ('zucchini', 2154),
#  ('skinless', 2140),
#  ('luau leaf', 2129),
#  ('cheddar cheese', 2096),
#  ('nutmeg', 2090),
#  ('semisweet chocolate', 2050),
#  ('rosemary', 2025),
#  ('white wine', 2017),
#  ('lime', 2002),
#  ('mushrooms', 1994),
#  ('cut', 1962),
#  ('dill', 1954),
#  ('ketchup', 1951),
#  ('coconut', 1914),
#  ('cream', 1907),
#  ('strawberries', 1891),
#  ('sesame oil', 1883),
#  ('white vinegar', 1850),
#  ('sprinkles rice wine vinegar', 1819),
#  ('mint leaves', 1814),
#  ('edam cheese', 1812),
#  ('maple syrup', 1805),
#  ('raisins', 1789),
#  ('ground beef', 1784),
#  ('mulato', 1767),
#  ('thyme leaves', 1750),
#  ('apricot sauce', 1713),
#  ('ground cloves', 1703),
#  ('dark brown sugar', 1669),
#  ('allspice', 1656),
#  ('apple', 1626),
#  ('sticks celery', 1564),
#  ('pectin powder', 1554),
#  ('capers', 1540),
#  ('margarine', 1511),
#  ('avocado', 1506),
#  ('cinnamon', 1473),
#  ('chicken', 1471),
#  ('sprigs thyme', 1465),
#  ('range', 1457),
#  ('ice cubes', 1446),
#  ('cucumber', 1443),
#  ('ths butter', 1442),
#  ('cabbage', 1441),
#  ('vanilla', 1437),
#  ('white onion', 1431),
#  ('ice', 1418),
#  ('whipping cream', 1418),
#  ('coarse salt', 1416),
#  ('warm water', 1382),
#  ('rice vinegar', 1370),
#  ('miso sauce', 1367),
#  ('rind zest', 1347),
#  ('mint', 1339),
#  ('spinach', 1334),
#  ('serrano vinegar', 1331),
#  ('banana', 1329),
#  ('sesame seeds', 1323),
#  ('sage', 1317),
#  ('panela cheese', 1309),
#  ('yolk', 1298),
#  ('pineapple', 1281),
#  ('vanilla bean', 1264),
#  ('lemons', 1248),
#  ('bay powder', 1247),
#  ('nut oil', 1247),
#  ('juice lemon', 1246),
#  ('pine nuts', 1245),
#  ('turmeric', 1235),
#  ('shortening', 1231),
#  ('black peppers', 1229),
#  ('gooseberries', 1143),
#  ('nut milk', 1125),
#  ('molasses', 1122),
#  ('generous corn syrup', 1114),
#  ('beans', 1112),
#  ('salmonberries', 1111),
#  ('banana extract', 1109),
#  ('cayenne', 1106),
#  ('tabasco pepper sauce', 1101),
#  ('wine', 1097),
#  ('tarragon', 1069),
#  ('boneless', 1059),
#  ('perfect potatoes', 1038),
#  ('fregula', 1036),
#  ('cooking water', 1035),
#  ('brandy', 1033),
#  ('nuts', 1027),
#  ('limes', 1014),
#  ('liquid butter', 1014),
#  ('cake flour', 996),
#  ('jalapeno', 988),
#  ('green beans', 978),
#  ('juice lime', 978),
#  ('green tea ice cream', 972),
#  ('asian style sea salt', 944),
#  ('horseradish', 934),
#  ('pan onion', 927),
#  ('sodium nonfat chicken broth', 916),
#  ('size white', 913),
#  ('caramel stick', 911),
#  ('whole cloves', 900),
#  ('cumin seeds', 894),
#  ('cream tartar', 891),
#  ('rosemary stalk', 891),
#  ('mozzarella', 885),
#  ('plain yogurt', 884),
#  ('vodka', 869),
#  ('white pepper', 868),
#  ('dark rum', 840),
#  ('lemon peel', 839),
#  ('ham', 833),
#  ('yukon gold potatoes', 829),
#  ('golden raisins', 819),
#  ('fenugreek seeds', 818),
#  ('flour tortillas', 815),
#  ('dry sherry', 791),
#  ('cornmeal', 790),
#  ('more for', 790),
#  ('mustard', 789),
#  ('fish sauce', 785),
#  ('garlic salt', 784),
#  ('peanut butter', 784),
#  ('barley wine', 783),
#  ('pickle juice', 771),
#  ('more for dusting', 769),
#  ('hot water', 768),
#  ('black olives', 764),
#  ('goat cheese', 763),
#  ('beef broth', 761),
#  ('bunch cilantro', 745),
#  ('well parsley', 740),
#  ('chinese rice', 739),
#  ('superfine sugar', 732),
#  ('cardamom', 731),
#  ('yellow bell pepper', 731),
#  ('green', 730),
#  ('thick celery', 727),
#  ('coriander seeds', 726),
#  ('vine tomatoes', 725),
#  ('rice', 718),
#  ('deli colby jack cheese', 710),
#  ('leeks', 710),
#  ('sauce', 704),
#  ('cheddar', 703),
#  ('carrot chunks', 700),
#  ('mango', 699),
#  ('caribbean seasoning', 694),
#  ('frozen peas', 693),
#  ('sweet cubes', 691),
#  ('bourbon', 689),
#  ('ground pork', 689),
#  ('hot walnuts', 689),
#  ('vegetable broth', 687),
#  ('sunburst squash', 682),
#  ('cubano peppers', 681),
#  ('sweet onion', 669),
#  ('sage leaves', 667),
#  ('apricots', 659),
#  ('cortlandmcintosh apples', 658),
#  ('walnut oil', 652),
#  ('rapid rise dry yeast', 644),
#  ('cherries', 637),
#  ('cauliflower', 633),
#  ('ice water', 632),
#  ('fennel', 628),
#  ('branches rosemary', 626),
#  ('panquehue cheese', 626),
#  ('rindless cheese', 626),
#  ('rosemary leaves', 624),
#  ('coarse ground black peppercorns', 621),
#  ('dry', 620),
#  ('egglant', 617),
#  ('cumin', 616),
#  ('peaches', 616),
#  ('hard eggs', 611),
#  ('orange peel', 610),
#  ('watermelon wedges', 607),
#  ('apple cider', 602),
#  ('lime wedges', 602),
#  ('zest lemon', 602),
#  ('pumpkin puree', 600),
#  ('chocolate', 596),
#  ('beer', 594),
#  ('pancetta', 592),
#  ('oranges', 591),
#  ('buratta cheese', 586),
#  ('key', 585),
#  ('vegetable stock', 585),
#  ('scallops', 583),
#  ('asparagus', 580),
#  ('yellow cornmeal', 580),
#  ('carrot dice', 574),
#  ('cut thin sticks', 569),
#  ('white stock', 562),
#  ('creame peche', 558),
#  ('salsa', 558),
#  ('frozen', 557),
#  ('jalpenenos', 556),
#  ('yellow mustard', 553),
#  ('peppers', 547),
#  ('barbecue sauce', 543),
#  ('fennel bulb', 542),
#  ('new onions', 541),
#  ('vegetable oil for frying', 540),
#  ('syrup', 539),
#  ('gin', 535),
#  ('spaghetti', 533),
#  ('dishes', 528),
#  ('boboli', 524),
#  ('rum', 523),
#  ('romaine escarole lettuce', 518),
#  ('spanish onion', 517),
#  ('zest', 517),
#  ('vinegar', 516),
#  ('beets', 513),
#  ('papalo leaves', 507),
#  ('baguette', 504),
#  ('orange liqueur', 501),
#  ('sharp cheddar cheese', 499),
#  ('club soda', 497),
#  ('broth like chicken', 496),
#  ('majoram', 490),
#  ('orange tomatoes', 488),
#  ('spicy beans', 487),
#  ('apple pie spice', 486),
#  ('salmon', 482),
#  ('spinach leaves', 481),
#  ('blackberries', 480),
#  ('mexican white rice', 478),
#  ('dates', 477),
#  ('lime zest', 477),
#  ('corn', 476),
#  ('kinome sprigs', 476),
#  ('ripe tomatoes', 474),
#  ('more for drizzling', 472),
#  ('vegetable shortening', 470),
#  ('bias celery', 465),
#  ('broccoli florets', 465),
#  ('food coloring', 458),
#  ('quinoa', 455),
#  ('leek', 454),
#  ('hoisin sauce', 453),
#  ('dry bread crumbs', 452),
#  ('iceberg lettuce', 452),
#  ('tamarillos', 451),
#  ('currants', 443),
#  ('leaves', 441),
#  ('shakes paprika', 441),
#  ('mirin', 437),
#  ('mussels', 436),
#  ('pistachios', 431),
#  ('wild turkey', 429),
#  ('chickpeas', 426),
#  ('green parts', 426),
#  ('old oats', 425),
#  ('seeds', 424),
#  ('high chocolate chocolate', 422),
#  ('heaping scallions', 421),
#  ('cracker crumbs', 419),
#  ('heaping flour', 419),
#  ('mead', 417),
#  ('parsnips', 417),
#  ('marshmallows', 415),
#  ('pumpkin', 415),
#  ('yellow squash', 413),
#  ('quick cooking oats', 412),
#  ('thick', 411),
#  ('scallion threads', 410),
#  ('green cabbage', 408),
#  ('tan olives', 403),
#  ('romano cheese', 402),
#  ('celery salt', 400),
#  ('size cucumber', 398),
#  ('lettuce', 397),
#  ('open leaves', 396),
#  ('tequila', 395),
#  ('cognac', 392),
#  ('warm mushrooms', 392),
#  ('plum halves', 389),
#  ('granny smith apple', 388),
#  ('mint sprigs', 388),
#  ('vegetable oil chicken broth', 384),
#  ('anchovy fillets', 383),
#  ('caraway seeds', 379),
#  ('meat', 379),
#  ('creamy peanut butter', 377),
#  ('clam juice', 375),
#  ('chai masala', 371),
#  ('gelatin', 370),
#  ('type sea salt', 370),
#  ('elk steak', 365),
#  ('white bread', 362),
#  ('lard', 360),
#  ('coriander', 359),
#  ('cloves', 358),
#  ('champagne', 356),
#  ('jalapeno cheddar', 356),
#  ('for pan', 355),
#  ('brussels sprouts', 354),
#  ('crumbs', 354),
#  ('miso powder', 354),
#  ('white grain rice', 354),
#  ('agave nectar', 353),
#  ('bittersweet', 351),
#  ('ground porcini mushrooms', 351),
#  ('organic cayenne pepper', 351),
#  ('vegetable', 351),
#  ('any seeds', 350),
#  ('spice hunter curry seasoning', 349),
#  ('bananas foster sauce', 346),
#  ('celery ribs', 345),
#  ('peas', 345),
#  ('chicken wings', 344),
#  ('couscous', 344),
#  ('whole almonds', 344),
#  ('cashews', 343),
#  ('baking potatoes', 341),
#  ('sprig rosemary', 341),
#  ('apple vinegar', 338),
#  ('white', 338),
#  ('sprig thyme', 336),
#  ('stems', 334),
#  ('asiago cheese', 333),
#  ('gruyere cheese', 333),
#  ('bliss potato', 331),
#  ('green pepper', 327),
#  ('juice', 327),
#  ('panko breadcrumbs', 327),
#  ('spice powder', 326),
#  ('cucumber sour cream', 325),
#  ('non oil', 324),
#  ('lump crabmeat', 323),
#  ('sazon seasoning', 322),
#  ('lengthwise', 321),
#  ('sweet', 321),
#  ('pork', 318),
#  ('whole eggs', 318),
#  ('extra for brushing', 317),
#  ('frache', 316),
#  ('mustard seeds', 315),
#  ('tenderloin fillets', 315),
#  ('skim milk', 314),
#  ('pears', 313),
#  ('eggplants', 312),
#  ('figs', 312),
#  ('garbanzo beans', 310),
#  ('snow peas', 310),
#  ('star anise', 309),
#  ('dark chocolate', 306),
#  ('dry vermouth', 304),
#  ('celery juice', 302),
#  ('seedless grapes', 302),
#  ('tahini', 302),
#  ('deli cut bacon', 301),
#  ('nameko mushrooms', 301),
#  ('new potatoes', 300),
#  ('brown rice', 297),
#  ('kale', 297),
#  ('snap peas', 296),
#  ('szechuan chiles', 295),
#  ('radicchio', 294),
#  ('sprig parsley leaves', 294),
#  ('feta', 293),
#  ('potato', 293),
#  ('saffron', 293),
#  ('ultra eggs', 292),
#  ('oaxacan cheese', 291),
#  ('basmati rice', 290),
#  ('sherry', 289),
#  ('twist macaroni', 288),
#  ('anko', 287),
#  ('rice flour', 287),
#  ('beef', 286),
#  ('bag frozen chestnuts', 285),
#  ('package linguine pasta', 284),
#  ('natural cooking spray', 283),
#  ('topping', 282),
#  ('strips bacon', 280),
#  ('jicama', 279),
#  ('provolone cheese', 279),
#  ('tomato puree', 279),
#  ('white mushrooms', 278),
#  ('bok choy', 277),
#  ('oil depth for frying', 275),
#  ('packageenoki mushrooms', 273),
#  ('seafood seasoning', 271),
#  ('ricotta', 270),
#  ('white beans', 268),
#  ('morello cherries', 267),
#  ('filling', 266),
#  ('licorice liqueur', 266),
#  ('rhubarb', 266),
#  ('jalapeo chiles', 265),
#  ('sweet orange', 265),
#  ('ground', 264),
#  ('marmalade', 264),
#  ('greek yogurt', 262),
#  ('peppercorns', 262),
#  ('reggiano cheese', 262),
#  ('whole', 262),
#  ('float rum', 261),
#  ('coffee', 260),
#  ('nut', 259),
#  ('tulips', 259),
#  ('melon', 258),
#  ('grapefruit wedges', 257),
#  ('lentils', 257),
#  ('ground lamb', 256),
#  ('chile flakes', 255),
#  ('chokes', 254)]

# %%
n, c = zip(*refiltered)
n = list(n)
n.remove("more")
n.remove("more for")
n.remove("more for dusting")
sorted(n)
# Out:
# ['agar flakes',
#  'agave nectar',
#  'allspice',
#  'almonds',
#  'anchovy fillets',
#  'anko',
#  'any seeds',
#  'apple',
#  'apple cider',
#  'apple pie spice',
#  'apple vinegar',
#  'apricot sauce',
#  'apricots',
#  'asiago cheese',
#  'asian style sea salt',
#  'asparagus',
#  'avocado',
#  'bacon',
#  'bag frozen chestnuts',
#  'baguette',
#  'baking potatoes',
#  'baking soda',
#  'banana',
#  'banana extract',
#  'bananas foster sauce',
#  'barbecue sauce',
#  'barley wine',
#  'basil',
#  'basmati rice',
#  'bay powder',
#  'bean broth',
#  'beans',
#  'beef',
#  'beef broth',
#  'beer',
#  'beets',
#  'bell pepper',
#  'betel leaves',
#  'bias celery',
#  'bittersweet',
#  'black olives',
#  'black peppers',
#  'blackberries',
#  'bliss potato',
#  'boboli',
#  'bok choy',
#  'boneless',
#  'bourbon',
#  'branches rosemary',
#  'brandy',
#  'broccoli florets',
#  'broth like chicken',
#  'brown rice',
#  'brown sugar',
#  'brunoise garlic',
#  'brussels sprouts',
#  'bulgar',
#  'bunch cilantro',
#  'buratta cheese',
#  'butter',
#  'buttermilk',
#  'cabbage',
#  'cake flour',
#  'capers',
#  'caramel stick',
#  'caraway seeds',
#  'cardamom',
#  'caribbean seasoning',
#  'carrot',
#  'carrot chunks',
#  'carrot dice',
#  'cashews',
#  'cauliflower',
#  'cayenne',
#  'celery',
#  'celery juice',
#  'celery ribs',
#  'celery salt',
#  'chai masala',
#  'champagne',
#  'cheddar',
#  'cheddar cheese',
#  'cherries',
#  'chicken',
#  'chicken stock',
#  'chicken wings',
#  'chickpeas',
#  'chile flakes',
#  'chili butter',
#  'chili powder',
#  'chinese rice',
#  'chipotle juice',
#  'chives',
#  'chocolate',
#  'chocolate sugar',
#  'chokes',
#  'cilantro',
#  'cinnamon',
#  'clam juice',
#  'cloves',
#  'club soda',
#  'coarse ground black peppercorns',
#  'coarse salt',
#  'cocoa powder',
#  'coconut',
#  'coffee',
#  'cognac',
#  'confectioners sugar',
#  'cooking water',
#  'coriander',
#  'coriander seeds',
#  'corn',
#  'cornmeal',
#  'cortlandmcintosh apples',
#  'couscous',
#  'cracker crumbs',
#  'cream',
#  'cream tartar',
#  'creame peche',
#  'creamy peanut butter',
#  'crumbs',
#  'cubano peppers',
#  'cucumber',
#  'cucumber sour cream',
#  'cumin',
#  'cumin seeds',
#  'currants',
#  'cut',
#  'cut thin sticks',
#  'dark brown sugar',
#  'dark chocolate',
#  'dark rum',
#  'dates',
#  'deli colby jack cheese',
#  'deli cut bacon',
#  'dill',
#  'dishes',
#  'dry',
#  'dry bread crumbs',
#  'dry sherry',
#  'dry vermouth',
#  'edam cheese',
#  'egg',
#  'egg whites',
#  'egglant',
#  'eggplants',
#  'eggs',
#  'elk steak',
#  'emon',
#  'extra for brushing',
#  'fennel',
#  'fennel bulb',
#  'fenugreek seeds',
#  'feta',
#  'figs',
#  'filling',
#  'fish sauce',
#  'float rum',
#  'flour',
#  'flour tortillas',
#  'food coloring',
#  'for cream',
#  'for pan',
#  'frache',
#  'fregula',
#  'frozen',
#  'frozen peas',
#  'garbanzo beans',
#  'garlic',
#  'garlic clove',
#  'garlic salt',
#  'garlic vinegar',
#  'gelatin',
#  'generous corn syrup',
#  'gin',
#  'ginger',
#  'goat cheese',
#  'gold metallic powder',
#  'golden raisins',
#  'gooseberries',
#  'granny smith apple',
#  'grapefruit wedges',
#  'greek yogurt',
#  'green',
#  'green beans',
#  'green cabbage',
#  'green onions',
#  'green parts',
#  'green pepper',
#  'green tea ice cream',
#  'ground',
#  'ground beef',
#  'ground cloves',
#  'ground cumin',
#  'ground lamb',
#  'ground porcini mushrooms',
#  'ground pork',
#  'gruyere cheese',
#  'ham',
#  'hard eggs',
#  'heaping flour',
#  'heaping scallions',
#  'high chocolate chocolate',
#  'hoisin sauce',
#  'homemade milk',
#  'honey',
#  'horseradish',
#  'hot pastry cream',
#  'hot walnuts',
#  'hot water',
#  'ice',
#  'ice cubes',
#  'ice water',
#  'iceberg lettuce',
#  'jalapeno',
#  'jalapeno cheddar',
#  'jalapeo chiles',
#  'jalpenenos',
#  'jicama',
#  'juice',
#  'juice lemon',
#  'juice lime',
#  'kale',
#  'ketchup',
#  'key',
#  'kinome sprigs',
#  'kocher salt',
#  'lard',
#  'leaves',
#  'leek',
#  'leeks',
#  'lemon peel',
#  'lemons',
#  'lengthwise',
#  'lentils',
#  'lettuce',
#  'licorice liqueur',
#  'lime',
#  'lime wedges',
#  'lime zest',
#  'limes',
#  'liquid butter',
#  'luau leaf',
#  'luau leaves',
#  'lump crabmeat',
#  'majoram',
#  'mango',
#  'maple syrup',
#  'margarine',
#  'marmalade',
#  'marshmallows',
#  'mayonnaise',
#  'mead',
#  'meat',
#  'melon',
#  'mexican white rice',
#  'milk',
#  'mint',
#  'mint leaves',
#  'mint sprigs',
#  'mirin',
#  'miso powder',
#  'miso sauce',
#  'molasses',
#  'more for drizzling',
#  'more zest',
#  'morello cherries',
#  'mozzarella',
#  'mulato',
#  'mushrooms',
#  'mussels',
#  'mustard',
#  'mustard seeds',
#  'nameko mushrooms',
#  'natural cooking spray',
#  'new onions',
#  'new potatoes',
#  'non oil',
#  'nut',
#  'nut milk',
#  'nut oil',
#  'nutmeg',
#  'nuts',
#  'oaxacan cheese',
#  'oil',
#  'oil depth for frying',
#  'old oats',
#  'olive oil',
#  'onion',
#  'open leaves',
#  'orange liqueur',
#  'orange peel',
#  'orange tomatoes',
#  'oranges',
#  'oregano',
#  'organic cayenne pepper',
#  'organic nutmeg',
#  'ounces garlic',
#  'package linguine pasta',
#  'packageenoki mushrooms',
#  'pan onion',
#  'pancetta',
#  'panela cheese',
#  'panko breadcrumbs',
#  'panquehue cheese',
#  'papalo leaves',
#  'paprika',
#  'parmesan',
#  'parmesan cheese',
#  'parsley leaves',
#  'parsnips',
#  'peaches',
#  'peanut butter',
#  'pears',
#  'peas',
#  'pecans',
#  'pectin powder',
#  'pepper',
#  'peppercorns',
#  'peppers',
#  'perfect potatoes',
#  'pickle juice',
#  'pine nuts',
#  'pineapple',
#  'pistachios',
#  'plain yogurt',
#  'plum halves',
#  'pork',
#  'pot barley',
#  'potato',
#  'potatoes',
#  'provolone cheese',
#  'pumpkin',
#  'pumpkin puree',
#  'quick cooking oats',
#  'quinoa',
#  'radicchio',
#  'raisins',
#  'range',
#  'rapid rise dry yeast',
#  'reggiano cheese',
#  'rhubarb',
#  'rice',
#  'rice flour',
#  'rice vinegar',
#  'ricotta',
#  'rind zest',
#  'rindless cheese',
#  'ripe tomatoes',
#  'romaine escarole lettuce',
#  'romano cheese',
#  'rosemary',
#  'rosemary leaves',
#  'rosemary stalk',
#  'rum',
#  'saffron',
#  'sage',
#  'sage leaves',
#  'salmon',
#  'salmonberries',
#  'salsa',
#  'salt',
#  'sauce',
#  'sazon seasoning',
#  'scallion',
#  'scallion threads',
#  'scallops',
#  'sea salt',
#  'seafood seasoning',
#  'seedless grapes',
#  'seeds',
#  'semisweet chocolate',
#  'serrano vinegar',
#  'sesame oil',
#  'sesame seeds',
#  'shakes paprika',
#  'shallot',
#  'sharp cheddar cheese',
#  'sherry',
#  'shortening',
#  'shrimp',
#  'size cucumber',
#  'size white',
#  'skim milk',
#  'skinless',
#  'snap peas',
#  'snow peas',
#  'sodium nonfat chicken broth',
#  'spaghetti',
#  'spanish onion',
#  'spice hunter curry seasoning',
#  'spice powder',
#  'spicy beans',
#  'spinach',
#  'spinach leaves',
#  'sprig parsley leaves',
#  'sprig rosemary',
#  'sprig thyme',
#  'sprigs thyme',
#  'sprinkles rice wine vinegar',
#  'sri lanka cinnamon',
#  'star anise',
#  'starch',
#  'stems',
#  'sticks celery',
#  'strawberries',
#  'strips bacon',
#  'sunburst squash',
#  'superfine sugar',
#  'sweet',
#  'sweet cubes',
#  'sweet onion',
#  'sweet orange',
#  'syrup',
#  'szechuan chiles',
#  'tabasco pepper sauce',
#  'tahini',
#  'tamarillos',
#  'tan olives',
#  'taro leaves',
#  'tarragon',
#  'tenderloin fillets',
#  'tequila',
#  'thick',
#  'thick celery',
#  'ths butter',
#  'thyme',
#  'thyme leaves',
#  'tomato paste',
#  'tomato puree',
#  'tomatoes',
#  'topping',
#  'tulips',
#  'turmeric',
#  'twist macaroni',
#  'type sea salt',
#  'ultra eggs',
#  'vanilla',
#  'vanilla bean',
#  'vegetable',
#  'vegetable broth',
#  'vegetable oil',
#  'vegetable oil chicken broth',
#  'vegetable oil for frying',
#  'vegetable shortening',
#  'vegetable stock',
#  'vine tomatoes',
#  'vinegar',
#  'vodka',
#  'walnut oil',
#  'walnuts',
#  'warm mushrooms',
#  'warm water',
#  'water',
#  'watermelon wedges',
#  'well parsley',
#  'whipping cream',
#  'white',
#  'white beans',
#  'white bread',
#  'white grain rice',
#  'white mushrooms',
#  'white onion',
#  'white pepper',
#  'white stock',
#  'white vinegar',
#  'white wine',
#  'whole',
#  'whole almonds',
#  'whole cloves',
#  'whole eggs',
#  'wild turkey',
#  'wine',
#  'wine vinegar',
#  'worecestershire sauce',
#  'yellow bell pepper',
#  'yellow cornmeal',
#  'yellow mustard',
#  'yellow squash',
#  'yolk',
#  'yukon gold potatoes',
#  'zest',
#  'zest lemon',
#  'zucchini']

# %%
re.split(r"\band\b|\bor\b|\bplus\b", "oregano and oranges andrew")
# Out:
# ['oregano ', ' oranges andrew']

# %%
"Ω" < "s"
# Out:
# False
